# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns

from matplotlib import pyplot as plt
from medcat.cat import CAT
# Out:
# C:\Users\BILAL\AppData\Roaming\Python\Python37\site-packages\medcat\cat.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Load model pack and Create CAT - the main class from medcat used for concept annotation

model_pack_path = 'medcat/mc_modelpack_snomed_int_16_mar_2022_25be3857ba34bdd5'
cat = CAT.load_model_pack(model_pack_path)
# Out:
# Found an existing unziped model pack at: medcat\mc_modelpack_snomed_int_16_mar_2022_25be3857ba34bdd5, the provided zip will not be touched.
# {
#   "Model ID": "25be3857ba34bdd5",
#   "Last Modifed On": "16 March 2022",
#   "History (from least to most recent)": [
#     "a474096eb4566638",
#     "009617d7ff372682"
#   ],
#   "Description": "SNOMED INT enriched with UMLS and trained unsupervised on MIMIC-III",
#   "Source Ontology": "SnomedCT_InternationalRF2_PRODUCTION_20210131T120000Z",
#   "Location": "MedCAT Rosalind machine, available for public download from https://github.com/CogStack/MedCAT",
#   "MetaCAT models": {
#     "Status": "Detects is a concept Affirmed or Negated/Hypothetical"
#   },
#   "Basic CDB Stats": {
#     "Number of concepts": 354448,
#     "Number of names": 2049216,
#     "Number of concepts that received training": 29674,
#     "Number of seen training examples in total": 20585988,
#     "Average training examples per concept": 693.7382220125362
#   },
#   "Performance": {
#     "ner": {},
#     "meta": {}
#   },
#   "Important Parameters (Partial view, all available in cat.config)": {
#     "config.ner['min_name_len']": {
#       "value": 3,
#       "description": "Minimum detection length (found terms/mentions shorter than this will not be detected)."
#     },
#     "config.ner['upper_case_limit_len']": {
#       "value": 4,
#       "description": "All detected terms shorter than this value have to be uppercase, otherwise they will be ignored."
#     },
#     "config.linking['similarity_threshold']": {
#       "value": 0.2,
#       "description": "If the confidence of the model is lower than this a detection will be ignore."
#     },
#     "config.general['spell_check']": {
#       "value": true,
#       "description": "Is spell checking enabled."
#     },
#     "config.general['spell_check_len_limit']": {
#       "value": 7,
#       "description": "Words shorter than this will not be spell checked."
#     }
#   }
# }

# %%
test_notes = pd.read_csv('MIMIC_IV_clean_test_set_4digitcode.csv')
test_notes
# Out:
#         Unnamed: 0   hadm_id  \
# 0                0  20000024
# 1                1  20000024
# 2                2  20000024
# 3                3  20000024
# 4                4  20000024
# ...            ...       ...
# 259313      259313  29998079
# 259314      259314  29998079
# 259315      259315  29998079
# 259316      259316  29998079
# 259317      259317  29998079
#
#                                                      text  subject_id  \
# 0       sex f medicine allergies aspirin chief complai...  16925328.0
# 1       sex f medicine allergies aspirin chief complai...  16925328.0
# 2       sex f medicine allergies aspirin chief complai...  16925328.0
# 3       sex f medicine allergies aspirin chief complai...  16925328.0
# 4       sex f medicine allergies aspirin chief complai...  16925328.0
# ...                                                   ...         ...
# 259313  sex f medicine allergies sulfamethoxazole prav...  16957952.0
# 259314  sex f medicine allergies sulfamethoxazole prav...  16957952.0
# 259315  sex f medicine allergies sulfamethoxazole prav...  16957952.0
# 259316  sex f medicine allergies sulfamethoxazole prav...  16957952.0
# 259317  sex f medicine allergies sulfamethoxazole prav...  16957952.0
#
#         seq_num icd_code  icd_version
# 0           1.0    D50.0         10.0
# 1           2.0    K52.1         10.0
# 2           3.0     I10.         10.0
# 3           4.0    E53.8         10.0
# 4           5.0    M81.0         10.0
# ...         ...      ...          ...
# 259313     13.0    D72.8         10.0
# 259314     14.0    I25.2         10.0
# 259315     15.0    G25.8         10.0
# 259316     16.0    M19.9         10.0
# 259317     17.0    Z68.2         10.0
#
# [259318 rows x 7 columns]

# %%
test_notes.drop(columns = ['Unnamed: 0'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27192\1524833295.py in <module>
# ----> 1 test_notes.drop(columns = ['Unnamed: 0'], inplace = True)
#
# D:\anaconda3\envs\new_python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\anaconda3\envs\new_python\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# D:\anaconda3\envs\new_python\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# D:\anaconda3\envs\new_python\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# D:\anaconda3\envs\new_python\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
unique_hadm_notes = test_notes[['hadm_id', 'text']].drop_duplicates(subset='hadm_id')

# %%
unique_hadm_notes
# Out:
#          hadm_id                                               text
# 0       20000024  sex f medicine allergies aspirin chief complai...
# 10      20002636  sex m medicine allergies prevacid ciprofloxaci...
# 27      20002800  sex f medicine allergies penicillins tetanus t...
# 58      20003013  sex m neurology allergies no known allergies a...
# 71      20003425  sex m otolaryngology allergies no known allerg...
# ...          ...                                                ...
# 259249  29996653  sex f medicine allergies erythromycin base ato...
# 259281  29996750  sex f medicine allergies ciprofloxacin codeine...
# 259289  29997523  sex f surgery allergies no known allergies adv...
# 259295  29997858  sex m medicine allergies no known allergies ad...
# 259301  29998079  sex f medicine allergies sulfamethoxazole prav...
#
# [18345 rows x 2 columns]

# %%
unique_hadm_notes = unique_hadm_notes.reset_index(drop = True)

# %%
icd10_data = {
    'hadm_id': [],
    'icd10_codes': []
}

# %%
i = 0
for index, row in unique_hadm_notes.iterrows():
    i +=1
    
    if i%100 ==0:
        print(f'{i} notes have been processed!', '\n')
        
        
    single_note = row['text']
    hadm_id = row['hadm_id']

    # Get the entities from the text
    all_entities = cat.get_entities(single_note)

    icd_codes = set()  # Using a set to automatically remove duplicates

    for entity_id, entity_data in all_entities['entities'].items():
        icd10 = entity_data.get('icd10', [])
        for code in icd10:
            if code:  # Check if the code is not an empty string
                icd_codes.add(code)

    icd10_data['hadm_id'].append(hadm_id)
    icd10_data['icd10_codes'].append(list(icd_codes))
# Out:
# 100 notes have been processed!
#
# 200 notes have been processed!
#
# 300 notes have been processed!
#
# 400 notes have been processed!
#
# 500 notes have been processed!
#
# 600 notes have been processed!
#
# 700 notes have been processed!
#
# 800 notes have been processed!
#
# 900 notes have been processed!
#
# 1000 notes have been processed!
#
# 1100 notes have been processed!
#
# 1200 notes have been processed!
#
# 1300 notes have been processed!
#
# 1400 notes have been processed!
#
# 1500 notes have been processed!
#
# 1600 notes have been processed!
#
# 1700 notes have been processed!
#
# 1800 notes have been processed!
#
# 1900 notes have been processed!
#
# 2000 notes have been processed!
#
# 2100 notes have been processed!
#
# 2200 notes have been processed!
#
# 2300 notes have been processed!
#
# 2400 notes have been processed!
#
# 2500 notes have been processed!
#
# 2600 notes have been processed!
#
# 2700 notes have been processed!
#
# 2800 notes have been processed!
#
# 2900 notes have been processed!
#
# 3000 notes have been processed!
#
# 3100 notes have been processed!
#
# 3200 notes have been processed!
#
# 3300 notes have been processed!
#
# 3400 notes have been processed!
#
# 3500 notes have been processed!
#
# 3600 notes have been processed!
#
# 3700 notes have been processed!
#
# 3800 notes have been processed!
#
# 3900 notes have been processed!
#
# 4000 notes have been processed!
#
# 4100 notes have been processed!
#
# 4200 notes have been processed!
#
# 4300 notes have been processed!
#
# 4400 notes have been processed!
#
# 4500 notes have been processed!
#
# 4600 notes have been processed!
#
# 4700 notes have been processed!
#
# 4800 notes have been processed!
#
# 4900 notes have been processed!
#
# 5000 notes have been processed!
#
# 5100 notes have been processed!
#
# 5200 notes have been processed!
#
# 5300 notes have been processed!
#
# 5400 notes have been processed!
#
# 5500 notes have been processed!
#
# 5600 notes have been processed!
#
# 5700 notes have been processed!
#
# 5800 notes have been processed!
#
# 5900 notes have been processed!
#
# 6000 notes have been processed!
#
# 6100 notes have been processed!
#
# 6200 notes have been processed!
#
# 6300 notes have been processed!
#
# 6400 notes have been processed!
#
# 6500 notes have been processed!
#
# 6600 notes have been processed!
#
# 6700 notes have been processed!
#
# 6800 notes have been processed!
#
# 6900 notes have been processed!
#
# 7000 notes have been processed!
#
# 7100 notes have been processed!
#
# 7200 notes have been processed!
#
# 7300 notes have been processed!
#
# 7400 notes have been processed!
#
# 7500 notes have been processed!
#
# 7600 notes have been processed!
#
# 7700 notes have been processed!
#
# 7800 notes have been processed!
#
# 7900 notes have been processed!
#
# 8000 notes have been processed!
#
# 8100 notes have been processed!
#
# 8200 notes have been processed!
#
# 8300 notes have been processed!
#
# 8400 notes have been processed!
#
# 8500 notes have been processed!
#
# 8600 notes have been processed!
#
# 8700 notes have been processed!
#
# 8800 notes have been processed!
#
# 8900 notes have been processed!
#
# 9000 notes have been processed!
#
# 9100 notes have been processed!
#
# 9200 notes have been processed!
#
# 9300 notes have been processed!
#
# 9400 notes have been processed!
#
# 9500 notes have been processed!
#
# 9600 notes have been processed!
#
# 9700 notes have been processed!
#
# 9800 notes have been processed!
#
# 9900 notes have been processed!
#
# 10000 notes have been processed!
#
# 10100 notes have been processed!
#
# 10200 notes have been processed!
#
# 10300 notes have been processed!
#
# 10400 notes have been processed!
#
# 10500 notes have been processed!
#
# 10600 notes have been processed!
#
# 10700 notes have been processed!
#
# 10800 notes have been processed!
#
# 10900 notes have been processed!
#
# 11000 notes have been processed!
#
# 11100 notes have been processed!
#
# 11200 notes have been processed!
#
# 11300 notes have been processed!
#
# 11400 notes have been processed!
#
# 11500 notes have been processed!
#
# 11600 notes have been processed!
#
# 11700 notes have been processed!
#
# 11800 notes have been processed!
#
# 11900 notes have been processed!
#
# 12000 notes have been processed!
#
# 12100 notes have been processed!
#
# 12200 notes have been processed!
#
# 12300 notes have been processed!
#
# 12400 notes have been processed!
#
# 12500 notes have been processed!
#
# 12600 notes have been processed!
#
# 12700 notes have been processed!
#
# 12800 notes have been processed!
#
# 12900 notes have been processed!
#
# 13000 notes have been processed!
#
# 13100 notes have been processed!
#
# 13200 notes have been processed!
#
# 13300 notes have been processed!
#
# 13400 notes have been processed!
#
# 13500 notes have been processed!
#
# 13600 notes have been processed!
#
# 13700 notes have been processed!
#
# 13800 notes have been processed!
#
# 13900 notes have been processed!
#
# 14000 notes have been processed!
#
# 14100 notes have been processed!
#
# 14200 notes have been processed!
#
# 14300 notes have been processed!
#
# 14400 notes have been processed!
#
# 14500 notes have been processed!
#
# 14600 notes have been processed!
#
# 14700 notes have been processed!
#
# 14800 notes have been processed!
#
# 14900 notes have been processed!
#
# 15000 notes have been processed!
#
# 15100 notes have been processed!
#
# 15200 notes have been processed!
#
# 15300 notes have been processed!
#
# 15400 notes have been processed!
#
# 15500 notes have been processed!
#
# 15600 notes have been processed!
#
# 15700 notes have been processed!
#
# 15800 notes have been processed!
#
# 15900 notes have been processed!
#
# 16000 notes have been processed!
#
# 16100 notes have been processed!
#
# 16200 notes have been processed!
#
# 16300 notes have been processed!
#
# 16400 notes have been processed!
#
# 16500 notes have been processed!
#
# 16600 notes have been processed!
#
# 16700 notes have been processed!
#
# 16800 notes have been processed!
#
# 16900 notes have been processed!
#
# 17000 notes have been processed!
#
# 17100 notes have been processed!
#
# 17200 notes have been processed!
#
# 17300 notes have been processed!
#
# 17400 notes have been processed!
#
# 17500 notes have been processed!
#
# 17600 notes have been processed!
#
# 17700 notes have been processed!
#
# 17800 notes have been processed!
#
# 17900 notes have been processed!
#
# 18000 notes have been processed!
#
# 18100 notes have been processed!
#
# 18200 notes have been processed!
#
# 18300 notes have been processed!

# %%
# Create a DataFrame from the processed data
df_icd10 = pd.DataFrame(icd10_data)
df_icd10
# Out:
#         hadm_id                                        icd10_codes
# 0      20000024  [M81.99, K66.1, R20.8, K52.9, K44.9, J30.4, N8...
# 1      20002636  [I51.8, R57.9, I42.9, I31.3, M10.99, G47.3, E7...
# 2      20002800  [I51.8, R35, F32.2, L03.9, N83.2, G62.9, R09.0...
# 3      20003013  [I64, R41.3, R50.8, R05, R25.2, A09.9, R47.0, ...
# 4      20003425  [T14.0, T81.9, R52.9, Z48.9, R06.2, R22.1, R29...
# ...         ...                                                ...
# 18340  29996653  [R13, J81, K11.7, I64, R05, G62.9, E78.5, E04....
# 18341  29996750  [R94.3, E27.8, I64, K44.9, E78.8, R50.8, Z73.3...
# 18342  29997523  [R33, I50.0, R63.0, R58, D64.9, R22.2, Z86.2, ...
# 18343  29997858  [R63.4, K57.9, R05, M25.59, R58, I51.9, R21, Z...
# 18344  29998079  [R63.4, M81.99, R20.8, D50.9, E28.3, R29.2, E4...
#
# [18345 rows x 2 columns]

# %%
# Define the reformat function
def reformat(code):
    code = ''.join(code.split('.'))
    if len(code) >3:
        code = code[:3] + '.' + code[3]
    else:
        code = code[:3] + '.'
    return code

# %%
# Apply the reformat function to each element in the 'icd10_codes' column
df_icd10['icd10_codes'] = df_icd10['icd10_codes'].apply(lambda codes: [reformat(code) for code in codes])
df_icd10
# Out:
#         hadm_id                                        icd10_codes
# 0      20000024  [M81.9, K66.1, R20.8, K52.9, K44.9, J30.4, N83...
# 1      20002636  [I51.8, R57.9, I42.9, I31.3, M10.9, G47.3, E78...
# 2      20002800  [I51.8, R35., F32.2, L03.9, N83.2, G62.9, R09....
# 3      20003013  [I64., R41.3, R50.8, R05., R25.2, A09.9, R47.0...
# 4      20003425  [T14.0, T81.9, R52.9, Z48.9, R06.2, R22.1, R29...
# ...         ...                                                ...
# 18340  29996653  [R13., J81., K11.7, I64., R05., G62.9, E78.5, ...
# 18341  29996750  [R94.3, E27.8, I64., K44.9, E78.8, R50.8, Z73....
# 18342  29997523  [R33., I50.0, R63.0, R58., D64.9, R22.2, Z86.2...
# 18343  29997858  [R63.4, K57.9, R05., M25.5, R58., I51.9, R21.,...
# 18344  29998079  [R63.4, M81.9, R20.8, D50.9, E28.3, R29.2, E46...
#
# [18345 rows x 2 columns]

# %%
# Define a function to remove duplicates within a list
def remove_duplicates(codes):
    seen = set()
    result = []
    for code in codes:
        if code not in seen:
            result.append(code)
            seen.add(code)
    return result

# %%
# Apply the remove_duplicates function to the 'icd10_codes' column for each 'hadm_id'
df_icd10['icd10_codes'] = df_icd10['icd10_codes'].apply(remove_duplicates)
df_icd10
# Out:
#         hadm_id                                        icd10_codes
# 0      20000024  [M81.9, K66.1, R20.8, K52.9, K44.9, J30.4, N83...
# 1      20002636  [I51.8, R57.9, I42.9, I31.3, M10.9, G47.3, E78...
# 2      20002800  [I51.8, R35., F32.2, L03.9, N83.2, G62.9, R09....
# 3      20003013  [I64., R41.3, R50.8, R05., R25.2, A09.9, R47.0...
# 4      20003425  [T14.0, T81.9, R52.9, Z48.9, R06.2, R22.1, R29...
# ...         ...                                                ...
# 18340  29996653  [R13., J81., K11.7, I64., R05., G62.9, E78.5, ...
# 18341  29996750  [R94.3, E27.8, I64., K44.9, E78.8, R50.8, Z73....
# 18342  29997523  [R33., I50.0, R63.0, R58., D64.9, R22.2, Z86.2...
# 18343  29997858  [R63.4, K57.9, R05., M25.5, R58., I51.9, R21.,...
# 18344  29998079  [R63.4, M81.9, R20.8, D50.9, E28.3, R29.2, E46...
#
# [18345 rows x 2 columns]

# %%
df_icd10.to_csv('test_set_mapped_icd_hadmids_18k_4digits.csv')

unique_hadm_notes.to_csv('test_set_unique_notes_hadmids_18k_4digits.csv')

# %%
df_icd10.dtypes
# Out:
# hadm_id         int64
# icd10_codes    object
# dtype: object

# %%
np.array(df_icd10[df_icd10.hadm_id==20000024].icd10_codes[0])
# Out:
# array(['M81.9', 'K66.1', 'R20.8', 'K52.9', 'K44.9', 'J30.4', 'N83.8',
#        'K57.9', 'K58.9', 'H40.9', 'A09.9', 'R58.', 'D64.9', 'K40.9',
#        'Z88.9', 'Q89.9', 'R23.0', 'R01.2', 'R60.9', 'C22.9', 'C34.9',
#        'R19.8', 'T14.0', 'C50.9', 'R32.', 'R01.1', 'R52.9', 'Z82.4',
#        'H35.3', 'R29.6', 'R27.0', 'S32.1', 'R71.', 'R06.2', 'R09.8',
#        'K59.0', 'M19.9', 'R53.'], dtype='<U5')

# %%
test_notes[test_notes.hadm_id == 20000024].icd_code.unique().astype('str')
# Out:
# array(['D50.0', 'K52.1', 'I10.', 'E53.8', 'M81.0', 'R27.0', 'Z91.8',
#        'H54.8', 'T47.4', 'Y92.0'], dtype='<U5')

# %%
df_icd10.drop_duplicates(subset = ['hadm_id'], inplace = True)

# %%
test_notes
# Out:
#          hadm_id                                               text  \
# 0       20000024  sex f medicine allergies aspirin chief complai...
# 1       20000024  sex f medicine allergies aspirin chief complai...
# 2       20000024  sex f medicine allergies aspirin chief complai...
# 3       20000024  sex f medicine allergies aspirin chief complai...
# 4       20000024  sex f medicine allergies aspirin chief complai...
# ...          ...                                                ...
# 259313  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259314  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259315  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259316  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259317  29998079  sex f medicine allergies sulfamethoxazole prav...
#
#         subject_id  seq_num icd_code  icd_version
# 0       16925328.0      1.0    D50.0         10.0
# 1       16925328.0      2.0    K52.1         10.0
# 2       16925328.0      3.0     I10.         10.0
# 3       16925328.0      4.0    E53.8         10.0
# 4       16925328.0      5.0    M81.0         10.0
# ...            ...      ...      ...          ...
# 259313  16957952.0     13.0    D72.8         10.0
# 259314  16957952.0     14.0    I25.2         10.0
# 259315  16957952.0     15.0    G25.8         10.0
# 259316  16957952.0     16.0    M19.9         10.0
# 259317  16957952.0     17.0    Z68.2         10.0
#
# [259318 rows x 6 columns]

# %%
unique_icd_codes = set(test_notes['icd_code']) #.union(set(icd_code for icd_list in df_icd10['icd10_codes'] for icd_code in icd_list))

# %%
len(unique_icd_codes)
# Out:
# 4330

# %%
test_notes.icd_code.nunique()
# Out:
# 4330

# %%
# Step 3: Initialize TP, FP, FN, TN counts
counts = {icd_code: (0, 0, 0, 0) for icd_code in unique_icd_codes}

# %%
i = 0
for icd_code in unique_icd_codes:
    i+=1
    if i%100 == 0:
        print(f'{i} codes are done!')
    
    true_icd_codes = test_notes[test_notes['icd_code'] == icd_code]['hadm_id'].values
    predicted_icd_codes = df_icd10[df_icd10['icd10_codes'].apply(lambda x: icd_code in x)]['hadm_id'].values

    TP = np.intersect1d(true_icd_codes, predicted_icd_codes)
    FP = np.setdiff1d(predicted_icd_codes, true_icd_codes)
    FN = np.setdiff1d(true_icd_codes, predicted_icd_codes)
    TN = len(np.union1d(predicted_icd_codes, true_icd_codes)) -len(TP) -len(FP) -len(FN)


    counts[icd_code] = (len(TP), len(FP), len(FN), TN)
# Out:
# 100 codes are done!
# 200 codes are done!
# 300 codes are done!
# 400 codes are done!
# 500 codes are done!
# 600 codes are done!
# 700 codes are done!
# 800 codes are done!
# 900 codes are done!
# 1000 codes are done!
# 1100 codes are done!
# 1200 codes are done!
# 1300 codes are done!
# 1400 codes are done!
# 1500 codes are done!
# 1600 codes are done!
# 1700 codes are done!
# 1800 codes are done!
# 1900 codes are done!
# 2000 codes are done!
# 2100 codes are done!
# 2200 codes are done!
# 2300 codes are done!
# 2400 codes are done!
# 2500 codes are done!
# 2600 codes are done!
# 2700 codes are done!
# 2800 codes are done!
# 2900 codes are done!
# 3000 codes are done!
# 3100 codes are done!
# 3200 codes are done!
# 3300 codes are done!
# 3400 codes are done!
# 3500 codes are done!
# 3600 codes are done!
# 3700 codes are done!
# 3800 codes are done!
# 3900 codes are done!
# 4000 codes are done!
# 4100 codes are done!
# 4200 codes are done!
# 4300 codes are done!

# %%
counts
# Out:
# {'T86.2': (0, 0, 3, 0),
#  'C71.9': (2, 18, 10, 0),
#  'I47.1': (159, 280, 146, 0),
#  'D25.1': (1, 0, 28, 0),
#  'Z53.8': (0, 0, 22, 0),
#  'F32.2': (7, 286, 3, 0),
#  'I73.8': (0, 76, 7, 0),
#  'L25.8': (0, 0, 3, 0),
#  'M46.1': (7, 17, 2, 0),
#  'Q63.8': (0, 1, 1, 0),
#  'R23.4': (3, 756, 8, 0),
#  'F31.5': (0, 0, 9, 0),
#  'D12.0': (0, 0, 22, 0),
#  'N50.8': (15, 104, 12, 0),
#  'R47.0': (176, 1146, 31, 0),
#  'G37.9': (1, 21, 2, 0),
#  'Z91.0': (1, 236, 37, 0),
#  'K25.4': (5, 13, 43, 0),
#  'C48.1': (0, 0, 5, 0),
#  'C32.0': (1, 2, 2, 0),
#  'N72.': (0, 0, 1, 0),
#  'C91.3': (0, 0, 2, 0),
#  'G40.5': (0, 8, 5, 0),
#  'L02.5': (0, 0, 16, 0),
#  'C09.9': (1, 4, 1, 0),
#  'G30.9': (136, 204, 27, 0),
#  'N28.9': (4, 1018, 44, 0),
#  'G97.3': (0, 0, 3, 0),
#  'N13.0': (0, 1, 10, 0),
#  'W10.1': (0, 0, 11, 0),
#  'Q65.8': (4, 3, 2, 0),
#  'O24.1': (0, 0, 6, 0),
#  'M75.0': (2, 31, 8, 0),
#  'I15.1': (0, 1, 4, 0),
#  'R25.9': (0, 0, 3, 0),
#  'D47.1': (4, 42, 2, 0),
#  'Y83.1': (0, 1, 225, 0),
#  'F40.0': (20, 16, 1, 0),
#  'R35.8': (0, 0, 11, 0),
#  'O36.8': (5, 51, 5, 0),
#  'G44.3': (1, 1, 6, 0),
#  'V23.4': (0, 0, 6, 0),
#  'L65.9': (2, 86, 2, 0),
#  'L89.6': (0, 0, 57, 0),
#  'R93.4': (0, 0, 7, 0),
#  'R40.3': (0, 0, 2, 0),
#  'R03.0': (3, 42, 37, 0),
#  'H53.4': (45, 94, 30, 0),
#  'M17.5': (0, 0, 1, 0),
#  'S46.9': (0, 0, 1, 0),
#  'B37.3': (14, 26, 25, 0),
#  'K12.1': (3, 158, 6, 0),
#  'F44.7': (0, 0, 2, 0),
#  'L27.0': (47, 52, 76, 0),
#  'Z43.4': (0, 0, 11, 0),
#  'Z77.2': (0, 0, 25, 0),
#  'I82.5': (0, 0, 45, 0),
#  'M41.9': (4, 11, 62, 0),
#  'B02.3': (6, 1, 4, 0),
#  'S91.0': (0, 1, 1, 0),
#  'Z51.0': (0, 0, 2, 0),
#  'W31.1': (0, 0, 1, 0),
#  'Q32.1': (0, 25, 2, 0),
#  'S43.5': (0, 0, 1, 0),
#  'S06.2': (1, 6, 12, 0),
#  'O86.1': (0, 0, 14, 0),
#  'A51.4': (2, 4, 0, 0),
#  'E22.2': (164, 115, 37, 0),
#  'N94.6': (8, 53, 2, 0),
#  'M48.5': (4, 26, 70, 0),
#  'R64.': (116, 242, 56, 0),
#  'W10.9': (0, 0, 94, 0),
#  'N99.5': (0, 0, 17, 0),
#  'H05.0': (6, 19, 1, 0),
#  'Q71.1': (0, 0, 1, 0),
#  'I95.2': (0, 0, 159, 0),
#  'N84.1': (1, 15, 2, 0),
#  'Z76.5': (1, 18, 8, 0),
#  'C67.8': (0, 0, 4, 0),
#  'K25.9': (38, 238, 48, 0),
#  'O43.8': (0, 4, 2, 0),
#  'N76.2': (0, 1, 1, 0),
#  'S42.0': (38, 24, 7, 0),
#  'K26.7': (0, 7, 1, 0),
#  'T40.0': (0, 0, 4, 0),
#  'K83.5': (1, 2, 0, 0),
#  'R63.5': (0, 224, 5, 0),
#  'E21.1': (0, 90, 3, 0),
#  'I97.0': (0, 0, 2, 0),
#  'I51.0': (0, 0, 4, 0),
#  'Z40.0': (0, 0, 10, 0),
#  'N73.9': (4, 18, 8, 0),
#  'F25.1': (0, 0, 3, 0),
#  'T79.1': (0, 1, 2, 0),
#  'T46.4': (0, 0, 41, 0),
#  'M51.9': (0, 0, 4, 0),
#  'J45.5': (0, 0, 21, 0),
#  'A19.9': (2, 6, 0, 0),
#  'O26.5': (0, 0, 3, 0),
#  'N05.9': (4, 80, 1, 0),
#  'M16.9': (0, 97, 1, 0),
#  'R14.0': (0, 0, 19, 0),
#  'F98.8': (0, 8, 12, 0),
#  'E83.9': (0, 0, 7, 0),
#  'I88.9': (2, 11, 2, 0),
#  'B35.6': (4, 5, 7, 0),
#  'G57.0': (1, 3, 0, 0),
#  'N65.1': (0, 0, 4, 0),
#  'Z76.8': (0, 0, 125, 0),
#  'O09.3': (0, 0, 1, 0),
#  'N94.8': (2, 345, 8, 0),
#  'S02.2': (27, 26, 9, 0),
#  'W13.0': (0, 0, 2, 0),
#  'B34.8': (6, 161, 2, 0),
#  'E07.8': (6, 43, 5, 0),
#  'M86.8': (0, 0, 73, 0),
#  'Y90.7': (0, 0, 8, 0),
#  'J10.0': (0, 0, 25, 0),
#  'L30.4': (14, 20, 10, 0),
#  'O99.2': (0, 1, 71, 0),
#  'Z92.2': (0, 7, 380, 0),
#  'C72.0': (0, 1, 1, 0),
#  'S89.9': (0, 36, 4, 0),
#  'G55.': (0, 0, 1, 0),
#  'S86.8': (0, 4, 2, 0),
#  'D63.0': (1, 0, 221, 0),
#  'N11.1': (0, 2, 4, 0),
#  'Z01.8': (0, 0, 4, 0),
#  'R39.2': (0, 0, 1, 0),
#  'E66.2': (36, 10, 36, 0),
#  'L60.0': (2, 5, 1, 0),
#  'J85.0': (8, 16, 2, 0),
#  'D76.2': (0, 0, 1, 0),
#  'G90.3': (0, 0, 8, 0),
#  'K05.2': (0, 2, 2, 0),
#  'T46.2': (8, 27, 26, 0),
#  'M84.7': (0, 0, 1, 0),
#  'N28.8': (26, 228, 27, 0),
#  'K56.7': (0, 0, 225, 0),
#  'D59.5': (0, 1, 1, 0),
#  'H20.9': (7, 34, 1, 0),
#  'M43.1': (31, 30, 19, 0),
#  'S90.4': (0, 0, 2, 0),
#  'R45.1': (92, 1850, 23, 0),
#  'H27.0': (1, 1, 0, 0),
#  'Q96.9': (2, 2, 1, 0),
#  'C15.8': (0, 0, 4, 0),
#  'J38.0': (17, 17, 11, 0),
#  'K56.3': (1, 3, 0, 0),
#  'J94.8': (39, 116, 8, 0),
#  'I95.8': (6, 26, 336, 0),
#  'K44.0': (1, 0, 8, 0),
#  'S15.1': (1, 1, 2, 0),
#  'R93.2': (0, 0, 8, 0),
#  'V47.6': (0, 0, 2, 0),
#  'L89.2': (0, 0, 11, 0),
#  'V17.0': (0, 0, 1, 0),
#  'C38.1': (0, 0, 2, 0),
#  'G47.4': (10, 17, 3, 0),
#  'V92.0': (0, 0, 1, 0),
#  'M21.7': (0, 6, 3, 0),
#  'K43.6': (6, 16, 2, 0),
#  'E61.0': (3, 3, 0, 0),
#  'B02.8': (0, 7, 5, 0),
#  'D57.8': (0, 0, 1, 0),
#  'B00.3': (0, 0, 2, 0),
#  'O30.1': (1, 0, 0, 0),
#  'J84.1': (55, 101, 37, 0),
#  'N42.8': (0, 4, 1, 0),
#  'K25.5': (3, 13, 1, 0),
#  'D17.1': (1, 1, 4, 0),
#  'C84.4': (5, 17, 1, 0),
#  'N82.2': (0, 0, 1, 0),
#  'R73.0': (132, 179, 68, 0),
#  'K62.6': (8, 10, 7, 0),
#  'D61.1': (0, 0, 5, 0),
#  'E83.5': (183, 1321, 111, 0),
#  'A41.2': (0, 0, 1, 0),
#  'N61.0': (0, 0, 5, 0),
#  'H40.5': (0, 6, 1, 0),
#  'N91.2': (0, 8, 1, 0),
#  'Z82.3': (0, 0, 71, 0),
#  'T74.2': (0, 2, 1, 0),
#  'S42.2': (0, 1, 44, 0),
#  'C54.1': (32, 29, 29, 0),
#  'G31.8': (1, 1, 129, 0),
#  'R47.1': (148, 994, 39, 0),
#  'I80.0': (0, 0, 10, 0),
#  'E21.2': (5, 8, 7, 0),
#  'B95.0': (0, 0, 7, 0),
#  'S90.3': (0, 0, 4, 0),
#  'I49.9': (7, 1251, 10, 0),
#  'Z87.3': (1, 146, 44, 0),
#  'M24.2': (0, 1, 1, 0),
#  'F84.0': (9, 16, 8, 0),
#  'Z03.8': (0, 0, 3, 0),
#  'C38.3': (0, 0, 2, 0),
#  'K63.0': (2, 2, 2, 0),
#  'R77.8': (0, 0, 6, 0),
#  'C57.9': (0, 0, 2, 0),
#  'M81.8': (0, 4, 10, 0),
#  'E87.5': (453, 173, 349, 0),
#  'K38.8': (1, 2, 3, 0),
#  'E87.6': (329, 109, 345, 0),
#  'Z83.7': (0, 0, 17, 0),
#  'K65.0': (0, 93, 1, 0),
#  'Q31.8': (0, 0, 1, 0),
#  'R40.0': (33, 1293, 30, 0),
#  'I61.0': (6, 19, 16, 0),
#  'Q99.8': (0, 3, 2, 0),
#  'K31.4': (0, 1, 2, 0),
#  'S01.5': (6, 22, 11, 0),
#  'S06.4': (0, 4, 8, 0),
#  'K91.0': (0, 0, 2, 0),
#  'C48.2': (2, 7, 2, 0),
#  'S61.4': (0, 0, 21, 0),
#  'K42.0': (11, 8, 6, 0),
#  'Y92.5': (0, 0, 69, 0),
#  'D84.1': (1, 6, 0, 0),
#  'S71.1': (0, 0, 8, 0),
#  'O74.5': (0, 0, 1, 0),
#  'F03.9': (0, 0, 521, 0),
#  'A07.2': (1, 0, 0, 0),
#  'L74.4': (1, 1, 0, 0),
#  'F72.': (0, 0, 9, 0),
#  'E63.8': (0, 0, 3, 0),
#  'F41.0': (70, 228, 25, 0),
#  'S26.0': (0, 0, 1, 0),
#  'G91.0': (4, 9, 4, 0),
#  'H90.3': (2, 5, 6, 0),
#  'Z45.0': (0, 3, 183, 0),
#  'R29.6': (32, 650, 33, 0),
#  'F43.9': (0, 0, 6, 0),
#  'M23.9': (0, 2, 2, 0),
#  'R82.1': (1, 7, 0, 0),
#  'M88.0': (1, 0, 0, 0),
#  'R27.0': (29, 408, 16, 0),
#  'B17.1': (2, 0, 2, 0),
#  'M46.2': (18, 16, 51, 0),
#  'D12.5': (0, 0, 18, 0),
#  'S20.0': (0, 0, 1, 0),
#  'D13.2': (0, 0, 13, 0),
#  'F55.3': (0, 0, 2, 0),
#  'I83.0': (0, 0, 18, 0),
#  'T84.7': (0, 0, 8, 0),
#  'M26.2': (0, 0, 1, 0),
#  'D48.7': (0, 46, 1, 0),
#  'L08.0': (2, 7, 1, 0),
#  'I21.A': (0, 0, 224, 0),
#  'N95.2': (2, 23, 4, 0),
#  'H11.4': (1, 180, 1, 0),
#  'D70.1': (0, 0, 65, 0),
#  'D56.9': (10, 30, 2, 0),
#  'R19.6': (1, 9, 0, 0),
#  'T40.6': (2, 59, 69, 0),
#  'I97.8': (0, 1, 143, 0),
#  'S02.5': (5, 20, 7, 0),
#  'L13.0': (0, 0, 1, 0),
#  'D49.7': (0, 0, 3, 0),
#  'M34.1': (10, 2, 5, 0),
#  'C77.0': (0, 0, 44, 0),
#  'K25.0': (0, 2, 3, 0),
#  'N05.7': (0, 0, 1, 0),
#  'H54.6': (0, 0, 41, 0),
#  'Z80.1': (0, 0, 126, 0),
#  'D72.8': (536, 2322, 419, 0),
#  'Z98.1': (0, 0, 180, 0),
#  'C34.3': (0, 0, 83, 0),
#  'M70.4': (1, 7, 2, 0),
#  'Z68.3': (0, 0, 1347, 0),
#  'C91.0': (4, 3, 23, 0),
#  'E10.5': (0, 0, 43, 0),
#  'K38.9': (1, 1, 0, 0),
#  'N14.2': (0, 0, 2, 0),
#  'K65.9': (11, 192, 9, 0),
#  'T37.0': (0, 0, 36, 0),
#  'D69.3': (24, 1, 42, 0),
#  'E07.9': (3, 198, 12, 0),
#  'B45.0': (2, 3, 2, 0),
#  'S36.6': (2, 3, 2, 0),
#  'R03.1': (0, 52, 1, 0),
#  'G24.0': (8, 26, 5, 0),
#  'I34.0': (295, 2856, 78, 0),
#  'J43.9': (19, 68, 157, 0),
#  'M54.8': (0, 32, 26, 0),
#  'D83.9': (23, 14, 1, 0),
#  'K92.1': (197, 2921, 23, 0),
#  'E87.4': (0, 2, 129, 0),
#  'I71.4': (101, 289, 79, 0),
#  'K31.6': (5, 9, 5, 0),
#  'T76.9': (0, 0, 1, 0),
#  'J68.0': (0, 6, 1, 0),
#  'G11.8': (0, 1, 1, 0),
#  'T37.4': (0, 0, 2, 0),
#  'I06.1': (0, 0, 1, 0),
#  'Z96.8': (0, 1, 25, 0),
#  'O04.5': (0, 0, 1, 0),
#  'K60.2': (10, 59, 2, 0),
#  'V03.0': (0, 0, 2, 0),
#  'S20.1': (0, 0, 2, 0),
#  'R82.4': (5, 28, 7, 0),
#  'O77.0': (0, 0, 3, 0),
#  'H53.0': (0, 17, 2, 0),
#  'E04.1': (109, 421, 43, 0),
#  'M75.4': (0, 4, 4, 0),
#  'B95.4': (0, 0, 73, 0),
#  'C25.0': (0, 0, 107, 0),
#  'G93.4': (94, 98, 394, 0),
#  'K61.1': (12, 46, 5, 0),
#  'M23.8': (0, 1, 1, 0),
#  'Y83.0': (7, 2, 182, 0),
#  'L73.8': (1, 0, 1, 0),
#  'R91.8': (0, 0, 249, 0),
#  'N20.9': (1, 44, 4, 0),
#  'Z43.0': (0, 0, 14, 0),
#  'M71.9': (2, 50, 2, 0),
#  'K13.0': (2, 45, 1, 0),
#  'H02.2': (1, 1, 0, 0),
#  'R20.3': (1, 26, 0, 0),
#  'N94.4': (3, 0, 0, 0),
#  'B85.2': (0, 0, 2, 0),
#  'Q27.8': (1, 6, 2, 0),
#  'G24.1': (0, 0, 3, 0),
#  'M48.3': (0, 0, 2, 0),
#  'H53.9': (3, 62, 9, 0),
#  'Q24.6': (1, 1, 0, 0),
#  'O68.': (0, 0, 1, 0),
#  'C10.9': (0, 1, 1, 0),
#  'G12.2': (10, 17, 11, 0),
#  'E28.3': (0, 82, 2, 0),
#  'S52.1': (4, 7, 3, 0),
#  'Z57.5': (0, 0, 1, 0),
#  'T65.9': (0, 682, 4, 0),
#  'J90.': (381, 4031, 36, 0),
#  'F42.3': (0, 0, 2, 0),
#  'D51.9': (0, 0, 51, 0),
#  'I97.4': (0, 0, 11, 0),
#  'V27.4': (0, 0, 2, 0),
#  'J01.9': (5, 55, 3, 0),
#  'T38.1': (0, 0, 7, 0),
#  'M67.8': (0, 20, 1, 0),
#  'H04.1': (27, 343, 12, 0),
#  'I16.9': (0, 0, 6, 0),
#  'O98.7': (0, 0, 2, 0),
#  'I70.1': (28, 100, 4, 0),
#  'R94.8': (0, 0, 5, 0),
#  'G46.7': (0, 35, 1, 0),
#  'B95.6': (42, 124, 289, 0),
#  'M72.8': (0, 0, 1, 0),
#  'L29.2': (0, 4, 2, 0),
#  'J69.8': (0, 0, 3, 0),
#  'F13.9': (0, 0, 5, 0),
#  'H10.8': (0, 0, 9, 0),
#  'I82.8': (0, 0, 47, 0),
#  'E61.1': (18, 397, 2, 0),
#  'L27.1': (0, 0, 34, 0),
#  'K75.1': (1, 0, 2, 0),
#  'W90.0': (0, 0, 2, 0),
#  'R82.7': (0, 6, 101, 0),
#  'K76.6': (232, 182, 220, 0),
#  'A41.5': (0, 0, 191, 0),
#  'S50.1': (0, 0, 5, 0),
#  'C44.9': (2, 265, 2, 0),
#  'Z20.5': (0, 0, 1, 0),
#  'B37.7': (2, 12, 10, 0),
#  'S00.2': (1, 16, 1, 0),
#  'C79.5': (110, 63, 196, 0),
#  'L84.': (2, 46, 2, 0),
#  'I31.9': (35, 224, 6, 0),
#  'Y78.3': (0, 0, 2, 0),
#  'X93.X': (0, 0, 2, 0),
#  'T42.6': (1, 1, 66, 0),
#  'D83.8': (0, 0, 1, 0),
#  'E85.3': (0, 2, 2, 0),
#  'N17.9': (1196, 333, 1662, 0),
#  'T68.X': (0, 0, 9, 0),
#  'S05.1': (0, 0, 11, 0),
#  'N84.0': (2, 39, 9, 0),
#  'N30.1': (10, 18, 2, 0),
#  'C26.1': (0, 1, 1, 0),
#  'E78.1': (49, 82, 11, 0),
#  'Z80.8': (0, 0, 84, 0),
#  'H51.2': (0, 0, 1, 0),
#  'N43.4': (1, 12, 0, 0),
#  'J93.0': (3, 9, 2, 0),
#  'G82.2': (55, 16, 18, 0),
#  'D36.7': (0, 1, 2, 0),
#  'K35.2': (0, 1, 17, 0),
#  'T50.Z': (0, 0, 8, 0),
#  'R81.': (5, 71, 2, 0),
#  'T42.5': (0, 0, 1, 0),
#  'M06.9': (234, 131, 79, 0),
#  'I13.1': (0, 0, 22, 0),
#  'B10.8': (0, 0, 2, 0),
#  'H54.4': (2, 5, 43, 0),
#  'G14.': (2, 8, 0, 0),
#  'K05.6': (2, 29, 4, 0),
#  'I08.0': (5, 4, 133, 0),
#  'S02.1': (24, 9, 20, 0),
#  'I87.2': (69, 77, 76, 0),
#  'Q87.2': (0, 1, 1, 0),
#  'Z90.6': (0, 0, 20, 0),
#  'C92.0': (15, 2, 107, 0),
#  'J45.4': (0, 0, 9, 0),
#  'N91.1': (1, 1, 0, 0),
#  'S40.8': (0, 0, 2, 0),
#  'E10.4': (0, 0, 186, 0),
#  'L89.3': (0, 0, 60, 0),
#  'Y84.8': (0, 0, 475, 0),
#  'T49.4': (0, 0, 1, 0),
#  'I65.2': (180, 354, 90, 0),
#  'R59.9': (0, 18, 12, 0),
#  'L40.9': (110, 177, 10, 0),
#  'Y08.8': (0, 0, 3, 0),
#  'Z57.3': (0, 0, 1, 0),
#  'K29.9': (0, 20, 1, 0),
#  'C70.0': (0, 0, 1, 0),
#  'O69.4': (1, 0, 0, 0),
#  'M33.9': (0, 0, 3, 0),
#  'L40.4': (0, 0, 2, 0),
#  'F32.9': (2075, 1112, 1332, 0),
#  'J34.1': (0, 0, 2, 0),
#  'Z83.6': (0, 0, 6, 0),
#  'I31.0': (0, 0, 1, 0),
#  'Z82.7': (0, 0, 4, 0),
#  'Q26.8': (1, 5, 3, 0),
#  'A41.8': (1, 2, 124, 0),
#  'J17.': (0, 0, 1, 0),
#  'I51.1': (0, 0, 11, 0),
#  'M24.0': (0, 2, 2, 0),
#  'G91.2': (14, 20, 7, 0),
#  'K80.7': (0, 0, 32, 0),
#  'N81.8': (0, 0, 2, 0),
#  'K74.5': (0, 5, 2, 0),
#  'S72.2': (1, 7, 19, 0),
#  'F31.6': (0, 0, 14, 0),
#  'D44.6': (0, 0, 3, 0),
#  'N71.0': (0, 0, 1, 0),
#  'C96.2': (0, 0, 1, 0),
#  'I26.0': (1, 2, 8, 0),
#  'G40.9': (136, 231, 381, 0),
#  'K12.0': (4, 4, 9, 0),
#  'C41.3': (0, 0, 1, 0),
#  'N80.9': (7, 88, 15, 0),
#  'E11.9': (367, 602, 1651, 0),
#  'H70.9': (4, 27, 0, 0),
#  'F45.4': (0, 3, 3, 0),
#  'C94.2': (2, 0, 1, 0),
#  'T78.1': (0, 0, 1, 0),
#  'X50.9': (0, 0, 5, 0),
#  'G46.8': (0, 0, 1, 0),
#  'V04.9': (0, 0, 1, 0),
#  'E70.3': (2, 4, 2, 0),
#  'S65.5': (0, 0, 4, 0),
#  'R91.1': (0, 0, 238, 0),
#  'T17.4': (0, 0, 2, 0),
#  'M54.1': (86, 131, 113, 0),
#  'T82.8': (2, 5, 331, 0),
#  'D18.0': (23, 200, 8, 0),
#  'O15.2': (0, 0, 1, 0),
#  'D27.0': (0, 0, 10, 0),
#  'R94.3': (27, 630, 51, 0),
#  'L89.5': (0, 0, 9, 0),
#  'R34.': (28, 238, 42, 0),
#  'G95.9': (7, 103, 5, 0),
#  'V49.8': (0, 0, 6, 0),
#  'O34.3': (0, 0, 11, 0),
#  'D15.0': (2, 23, 0, 0),
#  'T82.7': (2, 1, 46, 0),
#  'C61.': (142, 972, 11, 0),
#  'Z45.2': (0, 0, 2, 0),
#  'I95.3': (0, 0, 26, 0),
#  'D52.0': (0, 3, 7, 0),
#  'Q71.3': (0, 0, 1, 0),
#  'M70.5': (1, 2, 1, 0),
#  'F41.8': (1, 11, 131, 0),
#  'I23.7': (0, 0, 7, 0),
#  'K82.0': (1, 12, 3, 0),
#  'E88.2': (2, 19, 1, 0),
#  'I69.1': (0, 0, 46, 0),
#  'Y83.9': (0, 40, 30, 0),
#  'S54.2': (0, 1, 1, 0),
#  'R10.1': (143, 1164, 70, 0),
#  'S81.0': (5, 4, 9, 0),
#  'Q78.0': (1, 2, 0, 0),
#  'S64.1': (0, 0, 2, 0),
#  'C25.7': (0, 0, 6, 0),
#  'C91.6': (0, 0, 1, 0),
#  'M96.1': (0, 1, 1, 0),
#  'H35.8': (1, 18, 0, 0),
#  'D86.8': (2, 7, 26, 0),
#  'O62.3': (0, 0, 1, 0),
#  'J69.0': (267, 183, 145, 0),
#  'M16.5': (0, 0, 5, 0),
#  'E25.0': (2, 1, 0, 0),
#  'D75.A': (0, 0, 3, 0),
#  'K28.9': (5, 45, 3, 0),
#  'S72.3': (5, 7, 19, 0),
#  'K51.2': (3, 6, 1, 0),
#  'T43.6': (0, 0, 12, 0),
#  'M31.3': (7, 6, 0, 0),
#  'C83.5': (0, 0, 5, 0),
#  'J95.7': (0, 0, 6, 0),
#  'N05.5': (0, 1, 6, 0),
#  'G80.2': (0, 0, 1, 0),
#  'X50.3': (0, 0, 2, 0),
#  'C18.2': (0, 0, 30, 0),
#  'K26.0': (0, 0, 4, 0),
#  'Z82.5': (0, 0, 6, 0),
#  'D01.7': (0, 0, 3, 0),
#  'M95.8': (0, 18, 1, 0),
#  'O90.3': (1, 5, 0, 0),
#  'K90.9': (6, 40, 2, 0),
#  'H49.8': (0, 0, 1, 0),
#  'Y90.6': (0, 0, 10, 0),
#  'M22.2': (0, 4, 1, 0),
#  'R00.2': (47, 3012, 4, 0),
#  'J03.9': (3, 3, 0, 0),
#  'B37.4': (3, 5, 30, 0),
#  'L02.1': (6, 15, 5, 0),
#  'Z47.8': (0, 0, 1, 0),
#  'D66.': (9, 6, 3, 0),
#  'V27.0': (0, 0, 4, 0),
#  'A93.8': (0, 0, 3, 0),
#  'J38.7': (1, 2, 4, 0),
#  'D55.0': (0, 0, 23, 0),
#  'F12.2': (0, 1, 11, 0),
#  'R55.': (249, 2904, 37, 0),
#  'M08.2': (1, 6, 2, 0),
#  'O90.8': (0, 16, 30, 0),
#  'R74.8': (14, 44, 95, 0),
#  'F02.8': (0, 0, 276, 0),
#  'I42.9': (175, 856, 61, 0),
#  'K90.0': (59, 232, 4, 0),
#  'J34.0': (1, 3, 1, 0),
#  'H49.1': (1, 0, 4, 0),
#  'L80.': (3, 22, 0, 0),
#  'O22.3': (0, 0, 1, 0),
#  'E51.1': (2, 2, 0, 0),
#  'Y93.6': (0, 0, 3, 0),
#  'Z51.5': (0, 0, 627, 0),
#  'B35.3': (23, 14, 5, 0),
#  'W03.X': (0, 0, 2, 0),
#  'C73.': (20, 200, 1, 0),
#  'H16.8': (0, 2, 2, 0),
#  'K22.4': (49, 89, 7, 0),
#  'T36.1': (0, 0, 78, 0),
#  'W17.8': (0, 0, 47, 0),
#  'H47.1': (2, 105, 1, 0),
#  'I28.8': (1, 65, 4, 0),
#  'L40.5': (48, 26, 6, 0),
#  'Z81.4': (0, 0, 2, 0),
#  'E46.': (17, 40, 370, 0),
#  'Q82.8': (1, 20, 2, 0),
#  'Z18.1': (0, 0, 3, 0),
#  'Z51.6': (0, 0, 21, 0),
#  'O14.2': (0, 0, 3, 0),
#  'J86.0': (6, 7, 6, 0),
#  'S82.6': (2, 2, 10, 0),
#  'T42.7': (0, 0, 23, 0),
#  'N31.8': (0, 1, 22, 0),
#  'I05.1': (0, 0, 2, 0),
#  'L81.9': (1, 64, 2, 0),
#  'Z39.0': (0, 0, 1, 0),
#  'T48.2': (0, 0, 1, 0),
#  'G62.2': (0, 0, 8, 0),
#  'K04.7': (27, 58, 6, 0),
#  'I97.7': (0, 0, 16, 0),
#  'G11.9': (3, 2, 0, 0),
#  'Z59.7': (0, 0, 1, 0),
#  'S30.1': (0, 27, 10, 0),
#  'L73.9': (12, 28, 8, 0),
#  'Z65.3': (1, 16, 1, 0),
#  'G25.0': (71, 48, 11, 0),
#  'T36.3': (0, 0, 5, 0),
#  'Q24.5': (0, 13, 5, 0),
#  'S83.4': (1, 1, 2, 0),
#  'V09.9': (0, 0, 4, 0),
#  'B97.2': (0, 0, 2, 0),
#  'G89.2': (0, 0, 1155, 0),
#  'N48.3': (3, 6, 1, 0),
#  'Z20.6': (0, 0, 1, 0),
#  'J18.8': (10, 75, 17, 0),
#  'T49.1': (0, 0, 1, 0),
#  'D32.9': (0, 3, 12, 0),
#  'L98.8': (3, 810, 14, 0),
#  'K71.9': (2, 56, 0, 0),
#  'F80.9': (1, 15, 0, 0),
#  'J96.1': (46, 82, 56, 0),
#  'J32.8': (0, 0, 10, 0),
#  'I49.8': (9, 412, 26, 0),
#  'G71.0': (6, 5, 2, 0),
#  'C16.5': (0, 0, 2, 0),
#  'T36.6': (0, 0, 1, 0),
#  'Z20.8': (0, 0, 9, 0),
#  'S43.1': (1, 0, 2, 0),
#  'I15.0': (1, 0, 2, 0),
#  'R33.0': (0, 0, 27, 0),
#  'N32.8': (67, 195, 35, 0),
#  'G72.0': (5, 9, 10, 0),
#  'B95.5': (0, 1, 12, 0),
#  'S75.1': (0, 0, 1, 0),
#  'Y99.9': (0, 0, 4, 0),
#  'F73.': (0, 0, 1, 0),
#  'N05.1': (1, 15, 1, 0),
#  'L73.1': (0, 1, 1, 0),
#  'E89.1': (0, 1, 6, 0),
#  'Q86.0': (1, 2, 0, 0),
#  'I74.0': (0, 0, 7, 0),
#  'D68.2': (5, 31, 9, 0),
#  'V19.9': (3, 35, 2, 0),
#  'K75.8': (35, 183, 168, 0),
#  'K40.2': (6, 19, 2, 0),
#  'I50.3': (0, 0, 1734, 0),
#  'S09.2': (0, 0, 1, 0),
#  'Q43.8': (5, 6, 4, 0),
#  'I71.0': (44, 265, 9, 0),
#  'S71.0': (0, 0, 2, 0),
#  'Y93.3': (0, 0, 1, 0),
#  'M31.1': (6, 5, 5, 0),
#  'W55.0': (0, 0, 6, 0),
#  'J31.0': (23, 301, 6, 0),
#  'D63.1': (0, 0, 523, 0),
#  'G56.3': (4, 5, 0, 0),
#  'D05.8': (0, 0, 4, 0),
#  'M06.4': (1, 18, 4, 0),
#  'M96.3': (0, 1, 1, 0),
#  'J10.8': (0, 0, 6, 0),
#  'G37.2': (1, 7, 1, 0),
#  'M51.3': (18, 132, 38, 0),
#  'N70.1': (1, 20, 2, 0),
#  'N02.8': (20, 36, 3, 0),
#  'E27.2': (3, 23, 0, 0),
#  'N13.9': (17, 114, 8, 0),
#  'Z63.7': (0, 0, 3, 0),
#  'S64.3': (0, 0, 1, 0),
#  'C7A.1': (0, 0, 11, 0),
#  'M12.5': (0, 1, 4, 0),
#  'O86.8': (0, 0, 2, 0),
#  'G62.8': (2, 22, 28, 0),
#  'V43.5': (0, 0, 19, 0),
#  'T76.0': (0, 0, 4, 0),
#  'K91.2': (21, 1, 8, 0),
#  'D69.2': (2, 33, 3, 0),
#  'F01.5': (0, 0, 93, 0),
#  'Q92.8': (0, 0, 1, 0),
#  'C16.1': (0, 0, 2, 0),
#  'R40.4': (0, 0, 7, 0),
#  'O91.1': (0, 0, 1, 0),
#  'S44.0': (0, 0, 1, 0),
#  'C07.': (1, 6, 1, 0),
#  'S72.1': (50, 12, 21, 0),
#  'O99.5': (0, 0, 38, 0),
#  'C81.9': (6, 26, 19, 0),
#  'R82.9': (0, 419, 15, 0),
#  'Y08.0': (0, 0, 2, 0),
#  'D13.7': (0, 0, 2, 0),
#  'R93.5': (0, 0, 7, 0),
#  'N93.9': (24, 518, 8, 0),
#  'Z60.2': (3, 548, 4, 0),
#  'I24.0': (0, 10, 4, 0),
#  'O44.5': (0, 0, 1, 0),
#  'Z16.1': (0, 0, 43, 0),
#  'K60.1': (0, 0, 1, 0),
#  'T36.7': (0, 0, 4, 0),
#  'N81.3': (0, 0, 8, 0),
#  'G24.9': (5, 104, 3, 0),
#  'L03.9': (1, 788, 2, 0),
#  'X99.1': (0, 0, 6, 0),
#  'H57.1': (6, 71, 6, 0),
#  'O75.8': (0, 0, 10, 0),
#  'Z73.1': (0, 0, 1, 0),
#  'S10.9': (0, 24, 1, 0),
#  'E74.0': (0, 0, 10, 0),
#  'D06.7': (0, 0, 1, 0),
#  'S60.8': (0, 2, 5, 0),
#  'S36.3': (2, 1, 1, 0),
#  'Z22.1': (0, 0, 1, 0),
#  'Q62.0': (0, 1, 1, 0),
#  'F81.8': (0, 8, 2, 0),
#  'D56.1': (7, 4, 2, 0),
#  'M72.6': (15, 59, 3, 0),
#  'N32.9': (0, 5, 10, 0),
#  'L60.3': (0, 4, 1, 0),
#  'I95.1': (279, 210, 168, 0),
#  'C79.6': (0, 2, 22, 0),
#  'F90.8': (0, 0, 1, 0),
#  'K22.8': (2, 72, 20, 0),
#  'R12.': (2, 457, 4, 0),
#  'N80.0': (1, 0, 19, 0),
#  'Z33.1': (0, 0, 3, 0),
#  'C44.1': (0, 4, 1, 0),
#  'L22.': (0, 3, 1, 0),
#  'B58.2': (0, 2, 2, 0),
#  'D67.': (1, 1, 1, 0),
#  'K03.8': (0, 0, 6, 0),
#  'L95.9': (0, 1, 5, 0),
#  'A59.9': (0, 3, 2, 0),
#  'B17.8': (0, 0, 4, 0),
#  'Z46.2': (0, 0, 2, 0),
#  'Y01.X': (0, 0, 1, 0),
#  'C49.A': (0, 0, 7, 0),
#  'D84.8': (1, 3, 1, 0),
#  'T21.2': (0, 0, 2, 0),
#  'T48.1': (0, 0, 10, 0),
#  'I74.5': (2, 7, 7, 0),
#  'F88.': (0, 5, 4, 0),
#  'M77.1': (0, 8, 1, 0),
#  'E66.3': (0, 0, 39, 0),
#  'C49.9': (1, 140, 3, 0),
#  'Z94.8': (3, 2, 171, 0),
#  'Y90.3': (0, 0, 1, 0),
#  'R14.1': (0, 0, 2, 0),
#  'Y71.3': (0, 0, 19, 0),
#  'M79.6': (128, 1604, 88, 0),
#  'Y93.E': (0, 0, 3, 0),
#  'I67.6': (2, 4, 5, 0),
#  'M35.3': (76, 24, 44, 0),
#  'E26.9': (3, 25, 1, 0),
#  'B48.8': (0, 2, 12, 0),
#  'M18.1': (0, 0, 4, 0),
#  'H92.2': (2, 2, 0, 0),
#  'I63.9': (58, 577, 41, 0),
#  'D58.2': (2, 15, 0, 0),
#  'D49.4': (0, 0, 1, 0),
#  'M71.2': (0, 0, 8, 0),
#  'G62.1': (6, 1, 15, 0),
#  'S50.3': (0, 0, 7, 0),
#  'C22.7': (0, 3, 7, 0),
#  'Y65.8': (0, 0, 15, 0),
#  'S67.2': (0, 0, 1, 0),
#  'T83.6': (0, 0, 1, 0),
#  'L43.9': (2, 11, 0, 0),
#  'T84.5': (28, 14, 43, 0),
#  'J32.4': (1, 8, 5, 0),
#  'T84.2': (0, 1, 13, 0),
#  'O62.0': (0, 0, 2, 0),
#  'E60.': (0, 0, 5, 0),
#  'J95.4': (0, 0, 4, 0),
#  'Q67.5': (2, 163, 0, 0),
#  'K68.9': (0, 0, 2, 0),
#  'S30.8': (0, 80, 7, 0),
#  'Q04.0': (1, 2, 0, 0),
#  'J45.2': (0, 0, 38, 0),
#  'R57.8': (5, 13, 89, 0),
#  'J30.1': (0, 25, 3, 0),
#  'I44.7': (128, 142, 44, 0),
#  'S00.0': (1, 4, 28, 0),
#  'D73.4': (3, 1, 0, 0),
#  'Q55.6': (0, 0, 2, 0),
#  'K76.3': (3, 6, 2, 0),
#  'V03.1': (0, 0, 11, 0),
#  'G43.8': (1, 9, 39, 0),
#  'B96.6': (0, 0, 11, 0),
#  'K65.4': (0, 0, 9, 0),
#  'Y33.X': (0, 0, 3, 0),
#  'S24.0': (0, 0, 1, 0),
#  'J15.3': (0, 0, 2, 0),
#  'Z89.1': (0, 0, 3, 0),
#  'Z86.7': (318, 773, 2474, 0),
#  'Y93.0': (0, 0, 9, 0),
#  'C67.5': (0, 0, 1, 0),
#  'J43.8': (0, 0, 4, 0),
#  'B00.0': (0, 0, 1, 0),
#  'W20.8': (0, 0, 9, 0),
#  'S76.8': (0, 0, 1, 0),
#  'F95.2': (3, 2, 2, 0),
#  'M35.9': (4, 335, 1, 0),
#  'T48.3': (0, 11, 2, 0),
#  'M23.5': (1, 2, 0, 0),
#  'F50.2': (5, 46, 1, 0),
#  'N04.0': (0, 0, 2, 0),
#  'K46.0': (0, 0, 8, 0),
#  'O69.0': (5, 0, 0, 0),
#  'I77.1': (4, 116, 27, 0),
#  'D86.3': (3, 0, 0, 0),
#  'O69.8': (0, 0, 12, 0),
#  'C79.4': (2, 37, 15, 0),
#  'E56.8': (0, 0, 1, 0),
#  'J95.6': (0, 0, 2, 0),
#  'G93.0': (7, 30, 7, 0),
#  'H81.1': (12, 6, 34, 0),
#  'R23.3': (2, 342, 9, 0),
#  'H92.1': (0, 9, 1, 0),
#  'I73.1': (0, 0, 1, 0),
#  'S89.1': (0, 0, 3, 0),
#  'W34.0': (0, 0, 9, 0),
#  'Z63.6': (0, 0, 1, 0),
#  'G03.8': (1, 15, 2, 0),
#  'D33.1': (0, 0, 2, 0),
#  'T85.4': (0, 2, 4, 0),
#  'I87.3': (0, 0, 3, 0),
#  'R97.0': (0, 0, 1, 0),
#  'R09.8': (25, 9660, 12, 0),
#  'V49.5': (0, 0, 7, 0),
#  'H33.0': (0, 1, 1, 0),
#  'I99.8': (0, 0, 16, 0),
#  'I60.2': (0, 0, 3, 0),
#  'O21.8': (0, 0, 3, 0),
#  'K52.9': (48, 282, 120, 0),
#  'G40.B': (0, 0, 1, 0),
#  'K44.9': (174, 448, 54, 0),
#  'S42.3': (14, 92, 6, 0),
#  'Q60.2': (0, 6, 1, 0),
#  'R15.2': (0, 0, 1, 0),
#  'Z29.8': (0, 0, 2, 0),
#  'Z88.7': (0, 1, 2, 0),
#  'M79.2': (8, 153, 3, 0),
#  'Q04.8': (1, 68, 5, 0),
#  'S43.0': (6, 17, 0, 0),
#  'D25.9': (86, 570, 12, 0),
#  'F54.': (0, 0, 7, 0),
#  'R41.0': (25, 350, 181, 0),
#  'N40.2': (0, 0, 3, 0),
#  'V49.6': (0, 0, 1, 0),
#  'T41.2': (0, 0, 21, 0),
#  'D43.4': (1, 7, 0, 0),
#  'D49.0': (0, 0, 12, 0),
#  'E51.2': (9, 28, 1, 0),
#  'K11.6': (1, 3, 0, 0),
#  'J38.3': (11, 34, 14, 0),
#  'Y83.4': (0, 0, 63, 0),
#  'Q63.9': (1, 1, 0, 0),
#  'T80.6': (0, 1, 3, 0),
#  'Z57.2': (0, 0, 1, 0),
#  'R76.8': (0, 20, 4, 0),
#  'T81.8': (4, 352, 49, 0),
#  'E11.2': (0, 0, 1501, 0),
#  'D74.9': (2, 4, 0, 0),
#  'K83.8': (26, 803, 32, 0),
#  'D36.1': (4, 37, 4, 0),
#  'F16.9': (0, 0, 3, 0),
#  'R00.8': (1, 71, 19, 0),
#  'M24.8': (0, 1, 1, 0),
#  'T38.3': (4, 3, 56, 0),
#  'Q25.1': (2, 24, 1, 0),
#  'L30.1': (0, 0, 1, 0),
#  'A04.8': (0, 0, 4, 0),
#  'R53.1': (0, 0, 228, 0),
#  'I05.8': (1, 233, 1, 0),
#  'F68.1': (2, 9, 3, 0),
#  'K62.5': (12, 76, 48, 0),
#  'T46.1': (0, 0, 26, 0),
#  'D59.4': (0, 12, 14, 0),
#  'I09.8': (0, 0, 8, 0),
#  'N12.': (74, 269, 15, 0),
#  'K71.7': (0, 0, 1, 0),
#  'Z79.5': (0, 0, 185, 0),
#  'Z68.2': (0, 0, 930, 0),
#  'S05.0': (2, 2, 8, 0),
#  'Z97.8': (0, 0, 3, 0),
#  'Z3A.3': (0, 0, 120, 0),
#  'I82.B': (0, 0, 27, 0),
#  'S73.0': (3, 25, 1, 0),
#  'E41.': (1, 227, 0, 0),
#  'H57.0': (21, 312, 9, 0),
#  'T38.7': (0, 0, 3, 0),
#  'S83.5': (0, 1, 3, 0),
#  'Q79.6': (11, 11, 10, 0),
#  'H35.9': (0, 289, 3, 0),
#  'G58.7': (2, 4, 1, 0),
#  'L94.0': (0, 3, 1, 0),
#  'N99.3': (0, 0, 3, 0),
#  'K75.3': (2, 3, 2, 0),
#  'R82.8': (0, 1, 6, 0),
#  'O91.2': (1, 0, 0, 0),
#  'R20.8': (16, 3118, 9, 0),
#  'C53.0': (2, 0, 2, 0),
#  'R54.': (2, 190, 12, 0),
#  'E84.0': (0, 0, 1, 0),
#  'I23.6': (0, 0, 1, 0),
#  'D05.9': (0, 4, 2, 0),
#  'S39.9': (0, 148, 1, 0),
#  'C88.0': (9, 2, 2, 0),
#  'H10.9': (15, 41, 7, 0),
#  'H44.0': (1, 12, 1, 0),
#  'C43.4': (0, 0, 5, 0),
#  'Z77.1': (0, 0, 3, 0),
#  'M21.2': (0, 0, 1, 0),
#  'V00.1': (0, 0, 6, 0),
#  'I35.8': (3, 106, 6, 0),
#  'S68.6': (0, 0, 4, 0),
#  'T79.A': (0, 0, 8, 0),
#  'R09.2': (2, 31, 3, 0),
#  'K81.0': (49, 549, 3, 0),
#  'C92.1': (8, 3, 20, 0),
#  'R41.8': (92, 1920, 42, 0),
#  'N13.4': (10, 56, 4, 0),
#  'L05.9': (1, 24, 1, 0),
#  'K31.5': (22, 21, 9, 0),
#  'Z99.3': (0, 0, 264, 0),
#  'B37.0': (46, 33, 116, 0),
#  'M13.8': (0, 1, 31, 0),
#  'R58.': (12, 5810, 2, 0),
#  'D49.8': (0, 0, 1, 0),
#  'G89.4': (0, 0, 79, 0),
#  'H34.8': (4, 12, 2, 0),
#  'K62.3': (13, 24, 1, 0),
#  'O10.0': (0, 0, 2, 0),
#  'R29.8': (134, 2520, 121, 0),
#  'Z41.1': (0, 0, 3, 0),
#  'W05.0': (0, 0, 13, 0),
#  'D73.5': (43, 104, 4, 0),
#  'H81.3': (10, 15, 3, 0),
#  'J43.2': (13, 127, 4, 0),
#  'I82.6': (0, 0, 114, 0),
#  'T50.2': (0, 0, 56, 0),
#  'F33.3': (0, 0, 9, 0),
#  'I60.6': (0, 0, 3, 0),
#  'K64.4': (1, 2, 30, 0),
#  'J96.9': (139, 1031, 87, 0),
#  'H50.0': (1, 14, 1, 0),
#  'T76.1': (0, 0, 1, 0),
#  'Q39.6': (1, 10, 1, 0),
#  'F90.0': (4, 224, 0, 0),
#  'N30.9': (43, 205, 10, 0),
#  'S01.2': (0, 0, 8, 0),
#  'I82.C': (0, 0, 35, 0),
#  'I05.2': (0, 0, 8, 0),
#  'T84.4': (0, 0, 2, 0),
#  'N48.8': (2, 63, 8, 0),
#  'S91.1': (0, 0, 2, 0),
#  'Z93.8': (0, 0, 4, 0),
#  'M80.0': (0, 0, 14, 0),
#  'S64.0': (0, 0, 4, 0),
#  'T45.6': (0, 0, 9, 0),
#  'E86.0': (0, 0, 722, 0),
#  'G45.8': (1, 6, 2, 0),
#  'V20.4': (0, 0, 1, 0),
#  'Z85.8': (4, 4, 1041, 0),
#  'R05.': (154, 6422, 18, 0),
#  'R71.8': (0, 0, 1, 0),
#  'Q43.3': (1, 0, 2, 0),
#  'R40.2': (59, 1181, 110, 0),
#  'M06.0': (9, 14, 7, 0),
#  'I44.4': (1, 33, 4, 0),
#  'K50.0': (12, 13, 32, 0),
#  'I71.9': (4, 187, 1, 0),
#  'G04.8': (4, 7, 6, 0),
#  'Z89.9': (0, 2, 1, 0),
#  'S31.1': (0, 0, 4, 0),
#  'D17.9': (2, 106, 0, 0),
#  'S19.9': (0, 24, 2, 0),
#  'W11.X': (0, 0, 27, 0),
#  'G47.3': (848, 237, 1140, 0),
#  'R94.4': (0, 55, 15, 0),
#  'T75.8': (0, 0, 1, 0),
#  'C25.4': (0, 0, 3, 0),
#  'T87.4': (5, 2, 16, 0),
#  'N50.0': (1, 1, 2, 0),
#  'I44.3': (6, 184, 5, 0),
#  'R04.0': (67, 193, 17, 0),
#  'W51.X': (0, 0, 1, 0),
#  'G06.2': (2, 104, 0, 0),
#  'N92.5': (0, 0, 1, 0),
#  'T45.8': (0, 0, 25, 0),
#  'E72.8': (0, 0, 1, 0),
#  'G31.9': (6, 176, 5, 0),
#  'G47.2': (0, 128, 5, 0),
#  'R25.1': (45, 2312, 8, 0),
#  'B01.0': (0, 0, 1, 0),
#  'N71.1': (2, 1, 0, 0),
#  'S31.8': (0, 1, 3, 0),
#  'E03.8': (6, 71, 21, 0),
#  'S04.0': (0, 1, 1, 0),
#  'I49.1': (3, 49, 12, 0),
#  'H50.2': (2, 2, 0, 0),
#  'B96.7': (0, 0, 5, 0),
#  'D57.4': (0, 0, 1, 0),
#  'Z85.1': (0, 0, 174, 0),
#  'E88.0': (44, 47, 48, 0),
#  'I31.1': (3, 11, 0, 0),
#  'F15.9': (0, 4, 24, 0),
#  'K43.0': (7, 9, 21, 0),
#  'G72.9': (0, 2, 4, 0),
#  'F81.9': (7, 42, 5, 0),
#  'E23.6': (3, 46, 0, 0),
#  'K80.6': (0, 0, 29, 0),
#  'Q45.3': (6, 24, 0, 0),
#  'D43.1': (0, 6, 2, 0),
#  'S30.2': (3, 4, 0, 0),
#  'Y93.4': (0, 0, 1, 0),
#  'N64.8': (1, 15, 8, 0),
#  'H34.1': (3, 1, 0, 0),
#  'A02.0': (5, 2, 2, 0),
#  'E88.4': (0, 0, 11, 0),
#  'S12.2': (0, 0, 10, 0),
#  'K76.1': (28, 28, 44, 0),
#  'J45.3': (0, 0, 10, 0),
#  'O69.2': (0, 0, 2, 0),
#  'L30.9': (48, 168, 27, 0),
#  'D61.9': (13, 487, 2, 0),
#  'S40.0': (0, 1, 7, 0),
#  'Y04.1': (0, 0, 1, 0),
#  'D86.1': (0, 0, 3, 0),
#  'E03.9': (2091, 432, 188, 0),
#  'M26.4': (0, 0, 3, 0),
#  'I05.0': (5, 194, 4, 0),
#  'J39.2': (2, 359, 7, 0),
#  'S21.1': (0, 0, 4, 0),
#  ...}

# %%
# Calculate Precision and Recall for Each ICD-10 Code
precisions = {}
recalls = {}
for icd_code in unique_icd_codes:
    TP, FP, FN, TN = counts[icd_code]
    
    # Handle division by zero
    if TP + FP == 0:
        precision = 0
    else:
        precision = TP / (TP + FP)

    if TP + FN == 0:
        recall = 0
    else:
        recall = TP / (TP + FN)
    
    precisions[icd_code] = precision
    recalls[icd_code] = recall

# %%
precisions
# Out:
# {'T86.2': 0,
#  'C71.9': 0.1,
#  'I47.1': 0.3621867881548975,
#  'D25.1': 1.0,
#  'Z53.8': 0,
#  'F32.2': 0.023890784982935155,
#  'I73.8': 0.0,
#  'L25.8': 0,
#  'M46.1': 0.2916666666666667,
#  'Q63.8': 0.0,
#  'R23.4': 0.003952569169960474,
#  'F31.5': 0,
#  'D12.0': 0,
#  'N50.8': 0.12605042016806722,
#  'R47.0': 0.13313161875945537,
#  'G37.9': 0.045454545454545456,
#  'Z91.0': 0.004219409282700422,
#  'K25.4': 0.2777777777777778,
#  'C48.1': 0,
#  'C32.0': 0.3333333333333333,
#  'N72.': 0,
#  'C91.3': 0,
#  'G40.5': 0.0,
#  'L02.5': 0,
#  'C09.9': 0.2,
#  'G30.9': 0.4,
#  'N28.9': 0.003913894324853229,
#  'G97.3': 0,
#  'N13.0': 0.0,
#  'W10.1': 0,
#  'Q65.8': 0.5714285714285714,
#  'O24.1': 0,
#  'M75.0': 0.06060606060606061,
#  'I15.1': 0.0,
#  'R25.9': 0,
#  'D47.1': 0.08695652173913043,
#  'Y83.1': 0.0,
#  'F40.0': 0.5555555555555556,
#  'R35.8': 0,
#  'O36.8': 0.08928571428571429,
#  'G44.3': 0.5,
#  'V23.4': 0,
#  'L65.9': 0.022727272727272728,
#  'L89.6': 0,
#  'R93.4': 0,
#  'R40.3': 0,
#  'R03.0': 0.06666666666666667,
#  'H53.4': 0.3237410071942446,
#  'M17.5': 0,
#  'S46.9': 0,
#  'B37.3': 0.35,
#  'K12.1': 0.018633540372670808,
#  'F44.7': 0,
#  'L27.0': 0.47474747474747475,
#  'Z43.4': 0,
#  'Z77.2': 0,
#  'I82.5': 0,
#  'M41.9': 0.26666666666666666,
#  'B02.3': 0.8571428571428571,
#  'S91.0': 0.0,
#  'Z51.0': 0,
#  'W31.1': 0,
#  'Q32.1': 0.0,
#  'S43.5': 0,
#  'S06.2': 0.14285714285714285,
#  'O86.1': 0,
#  'A51.4': 0.3333333333333333,
#  'E22.2': 0.5878136200716846,
#  'N94.6': 0.13114754098360656,
#  'M48.5': 0.13333333333333333,
#  'R64.': 0.3240223463687151,
#  'W10.9': 0,
#  'N99.5': 0,
#  'H05.0': 0.24,
#  'Q71.1': 0,
#  'I95.2': 0,
#  'N84.1': 0.0625,
#  'Z76.5': 0.05263157894736842,
#  'C67.8': 0,
#  'K25.9': 0.13768115942028986,
#  'O43.8': 0.0,
#  'N76.2': 0.0,
#  'S42.0': 0.6129032258064516,
#  'K26.7': 0.0,
#  'T40.0': 0,
#  'K83.5': 0.3333333333333333,
#  'R63.5': 0.0,
#  'E21.1': 0.0,
#  'I97.0': 0,
#  'I51.0': 0,
#  'Z40.0': 0,
#  'N73.9': 0.18181818181818182,
#  'F25.1': 0,
#  'T79.1': 0.0,
#  'T46.4': 0,
#  'M51.9': 0,
#  'J45.5': 0,
#  'A19.9': 0.25,
#  'O26.5': 0,
#  'N05.9': 0.047619047619047616,
#  'M16.9': 0.0,
#  'R14.0': 0,
#  'F98.8': 0.0,
#  'E83.9': 0,
#  'I88.9': 0.15384615384615385,
#  'B35.6': 0.4444444444444444,
#  'G57.0': 0.25,
#  'N65.1': 0,
#  'Z76.8': 0,
#  'O09.3': 0,
#  'N94.8': 0.005763688760806916,
#  'S02.2': 0.5094339622641509,
#  'W13.0': 0,
#  'B34.8': 0.03592814371257485,
#  'E07.8': 0.12244897959183673,
#  'M86.8': 0,
#  'Y90.7': 0,
#  'J10.0': 0,
#  'L30.4': 0.4117647058823529,
#  'O99.2': 0.0,
#  'Z92.2': 0.0,
#  'C72.0': 0.0,
#  'S89.9': 0.0,
#  'G55.': 0,
#  'S86.8': 0.0,
#  'D63.0': 1.0,
#  'N11.1': 0.0,
#  'Z01.8': 0,
#  'R39.2': 0,
#  'E66.2': 0.782608695652174,
#  'L60.0': 0.2857142857142857,
#  'J85.0': 0.3333333333333333,
#  'D76.2': 0,
#  'G90.3': 0,
#  'K05.2': 0.0,
#  'T46.2': 0.22857142857142856,
#  'M84.7': 0,
#  'N28.8': 0.10236220472440945,
#  'K56.7': 0,
#  'D59.5': 0.0,
#  'H20.9': 0.17073170731707318,
#  'M43.1': 0.5081967213114754,
#  'S90.4': 0,
#  'R45.1': 0.04737384140061792,
#  'H27.0': 0.5,
#  'Q96.9': 0.5,
#  'C15.8': 0,
#  'J38.0': 0.5,
#  'K56.3': 0.25,
#  'J94.8': 0.25161290322580643,
#  'I95.8': 0.1875,
#  'K44.0': 1.0,
#  'S15.1': 0.5,
#  'R93.2': 0,
#  'V47.6': 0,
#  'L89.2': 0,
#  'V17.0': 0,
#  'C38.1': 0,
#  'G47.4': 0.37037037037037035,
#  'V92.0': 0,
#  'M21.7': 0.0,
#  'K43.6': 0.2727272727272727,
#  'E61.0': 0.5,
#  'B02.8': 0.0,
#  'D57.8': 0,
#  'B00.3': 0,
#  'O30.1': 1.0,
#  'J84.1': 0.3525641025641026,
#  'N42.8': 0.0,
#  'K25.5': 0.1875,
#  'D17.1': 0.5,
#  'C84.4': 0.22727272727272727,
#  'N82.2': 0,
#  'R73.0': 0.42443729903536975,
#  'K62.6': 0.4444444444444444,
#  'D61.1': 0,
#  'E83.5': 0.12167553191489362,
#  'A41.2': 0,
#  'N61.0': 0,
#  'H40.5': 0.0,
#  'N91.2': 0.0,
#  'Z82.3': 0,
#  'T74.2': 0.0,
#  'S42.2': 0.0,
#  'C54.1': 0.5245901639344263,
#  'G31.8': 0.5,
#  'R47.1': 0.1295971978984238,
#  'I80.0': 0,
#  'E21.2': 0.38461538461538464,
#  'B95.0': 0,
#  'S90.3': 0,
#  'I49.9': 0.005564387917329093,
#  'Z87.3': 0.006802721088435374,
#  'M24.2': 0.0,
#  'F84.0': 0.36,
#  'Z03.8': 0,
#  'C38.3': 0,
#  'K63.0': 0.5,
#  'R77.8': 0,
#  'C57.9': 0,
#  'M81.8': 0.0,
#  'E87.5': 0.7236421725239617,
#  'K38.8': 0.3333333333333333,
#  'E87.6': 0.7511415525114156,
#  'Z83.7': 0,
#  'K65.0': 0.0,
#  'Q31.8': 0,
#  'R40.0': 0.024886877828054297,
#  'I61.0': 0.24,
#  'Q99.8': 0.0,
#  'K31.4': 0.0,
#  'S01.5': 0.21428571428571427,
#  'S06.4': 0.0,
#  'K91.0': 0,
#  'C48.2': 0.2222222222222222,
#  'S61.4': 0,
#  'K42.0': 0.5789473684210527,
#  'Y92.5': 0,
#  'D84.1': 0.14285714285714285,
#  'S71.1': 0,
#  'O74.5': 0,
#  'F03.9': 0,
#  'A07.2': 1.0,
#  'L74.4': 0.5,
#  'F72.': 0,
#  'E63.8': 0,
#  'F41.0': 0.2348993288590604,
#  'S26.0': 0,
#  'G91.0': 0.3076923076923077,
#  'H90.3': 0.2857142857142857,
#  'Z45.0': 0.0,
#  'R29.6': 0.0469208211143695,
#  'F43.9': 0,
#  'M23.9': 0.0,
#  'R82.1': 0.125,
#  'M88.0': 1.0,
#  'R27.0': 0.06636155606407322,
#  'B17.1': 1.0,
#  'M46.2': 0.5294117647058824,
#  'D12.5': 0,
#  'S20.0': 0,
#  'D13.2': 0,
#  'F55.3': 0,
#  'I83.0': 0,
#  'T84.7': 0,
#  'M26.2': 0,
#  'D48.7': 0.0,
#  'L08.0': 0.2222222222222222,
#  'I21.A': 0,
#  'N95.2': 0.08,
#  'H11.4': 0.0055248618784530384,
#  'D70.1': 0,
#  'D56.9': 0.25,
#  'R19.6': 0.1,
#  'T40.6': 0.03278688524590164,
#  'I97.8': 0.0,
#  'S02.5': 0.2,
#  'L13.0': 0,
#  'D49.7': 0,
#  'M34.1': 0.8333333333333334,
#  'C77.0': 0,
#  'K25.0': 0.0,
#  'N05.7': 0,
#  'H54.6': 0,
#  'Z80.1': 0,
#  'D72.8': 0.18754373687893633,
#  'Z98.1': 0,
#  'C34.3': 0,
#  'M70.4': 0.125,
#  'Z68.3': 0,
#  'C91.0': 0.5714285714285714,
#  'E10.5': 0,
#  'K38.9': 0.5,
#  'N14.2': 0,
#  'K65.9': 0.054187192118226604,
#  'T37.0': 0,
#  'D69.3': 0.96,
#  'E07.9': 0.014925373134328358,
#  'B45.0': 0.4,
#  'S36.6': 0.4,
#  'R03.1': 0.0,
#  'G24.0': 0.23529411764705882,
#  'I34.0': 0.09362107267534116,
#  'J43.9': 0.21839080459770116,
#  'M54.8': 0.0,
#  'D83.9': 0.6216216216216216,
#  'K92.1': 0.06318152661962796,
#  'E87.4': 0.0,
#  'I71.4': 0.258974358974359,
#  'K31.6': 0.35714285714285715,
#  'T76.9': 0,
#  'J68.0': 0.0,
#  'G11.8': 0.0,
#  'T37.4': 0,
#  'I06.1': 0,
#  'Z96.8': 0.0,
#  'O04.5': 0,
#  'K60.2': 0.14492753623188406,
#  'V03.0': 0,
#  'S20.1': 0,
#  'R82.4': 0.15151515151515152,
#  'O77.0': 0,
#  'H53.0': 0.0,
#  'E04.1': 0.20566037735849058,
#  'M75.4': 0.0,
#  'B95.4': 0,
#  'C25.0': 0,
#  'G93.4': 0.4895833333333333,
#  'K61.1': 0.20689655172413793,
#  'M23.8': 0.0,
#  'Y83.0': 0.7777777777777778,
#  'L73.8': 1.0,
#  'R91.8': 0,
#  'N20.9': 0.022222222222222223,
#  'Z43.0': 0,
#  'M71.9': 0.038461538461538464,
#  'K13.0': 0.0425531914893617,
#  'H02.2': 0.5,
#  'R20.3': 0.037037037037037035,
#  'N94.4': 1.0,
#  'B85.2': 0,
#  'Q27.8': 0.14285714285714285,
#  'G24.1': 0,
#  'M48.3': 0,
#  'H53.9': 0.046153846153846156,
#  'Q24.6': 0.5,
#  'O68.': 0,
#  'C10.9': 0.0,
#  'G12.2': 0.37037037037037035,
#  'E28.3': 0.0,
#  'S52.1': 0.36363636363636365,
#  'Z57.5': 0,
#  'T65.9': 0.0,
#  'J90.': 0.08635539437896646,
#  'F42.3': 0,
#  'D51.9': 0,
#  'I97.4': 0,
#  'V27.4': 0,
#  'J01.9': 0.08333333333333333,
#  'T38.1': 0,
#  'M67.8': 0.0,
#  'H04.1': 0.07297297297297298,
#  'I16.9': 0,
#  'O98.7': 0,
#  'I70.1': 0.21875,
#  'R94.8': 0,
#  'G46.7': 0.0,
#  'B95.6': 0.25301204819277107,
#  'M72.8': 0,
#  'L29.2': 0.0,
#  'J69.8': 0,
#  'F13.9': 0,
#  'H10.8': 0,
#  'I82.8': 0,
#  'E61.1': 0.043373493975903614,
#  'L27.1': 0,
#  'K75.1': 1.0,
#  'W90.0': 0,
#  'R82.7': 0.0,
#  'K76.6': 0.5603864734299517,
#  'A41.5': 0,
#  'S50.1': 0,
#  'C44.9': 0.00749063670411985,
#  'Z20.5': 0,
#  'B37.7': 0.14285714285714285,
#  'S00.2': 0.058823529411764705,
#  'C79.5': 0.6358381502890174,
#  'L84.': 0.041666666666666664,
#  'I31.9': 0.13513513513513514,
#  'Y78.3': 0,
#  'X93.X': 0,
#  'T42.6': 0.5,
#  'D83.8': 0,
#  'E85.3': 0.0,
#  'N17.9': 0.7822105951602355,
#  'T68.X': 0,
#  'S05.1': 0,
#  'N84.0': 0.04878048780487805,
#  'N30.1': 0.35714285714285715,
#  'C26.1': 0.0,
#  'E78.1': 0.37404580152671757,
#  'Z80.8': 0,
#  'H51.2': 0,
#  'N43.4': 0.07692307692307693,
#  'J93.0': 0.25,
#  'G82.2': 0.7746478873239436,
#  'D36.7': 0.0,
#  'K35.2': 0.0,
#  'T50.Z': 0,
#  'R81.': 0.06578947368421052,
#  'T42.5': 0,
#  'M06.9': 0.6410958904109589,
#  'I13.1': 0,
#  'B10.8': 0,
#  'H54.4': 0.2857142857142857,
#  'G14.': 0.2,
#  'K05.6': 0.06451612903225806,
#  'I08.0': 0.5555555555555556,
#  'S02.1': 0.7272727272727273,
#  'I87.2': 0.4726027397260274,
#  'Q87.2': 0.0,
#  'Z90.6': 0,
#  'C92.0': 0.8823529411764706,
#  'J45.4': 0,
#  'N91.1': 0.5,
#  'S40.8': 0,
#  'E10.4': 0,
#  'L89.3': 0,
#  'Y84.8': 0,
#  'T49.4': 0,
#  'I65.2': 0.33707865168539325,
#  'R59.9': 0.0,
#  'L40.9': 0.3832752613240418,
#  'Y08.8': 0,
#  'Z57.3': 0,
#  'K29.9': 0.0,
#  'C70.0': 0,
#  'O69.4': 1.0,
#  'M33.9': 0,
#  'L40.4': 0,
#  'F32.9': 0.6510825227486664,
#  'J34.1': 0,
#  'Z83.6': 0,
#  'I31.0': 0,
#  'Z82.7': 0,
#  'Q26.8': 0.16666666666666666,
#  'A41.8': 0.3333333333333333,
#  'J17.': 0,
#  'I51.1': 0,
#  'M24.0': 0.0,
#  'G91.2': 0.4117647058823529,
#  'K80.7': 0,
#  'N81.8': 0,
#  'K74.5': 0.0,
#  'S72.2': 0.125,
#  'F31.6': 0,
#  'D44.6': 0,
#  'N71.0': 0,
#  'C96.2': 0,
#  'I26.0': 0.3333333333333333,
#  'G40.9': 0.37057220708446864,
#  'K12.0': 0.5,
#  'C41.3': 0,
#  'N80.9': 0.07368421052631578,
#  'E11.9': 0.37874097007223945,
#  'H70.9': 0.12903225806451613,
#  'F45.4': 0.0,
#  'C94.2': 1.0,
#  'T78.1': 0,
#  'X50.9': 0,
#  'G46.8': 0,
#  'V04.9': 0,
#  'E70.3': 0.3333333333333333,
#  'S65.5': 0,
#  'R91.1': 0,
#  'T17.4': 0,
#  'M54.1': 0.39631336405529954,
#  'T82.8': 0.2857142857142857,
#  'D18.0': 0.1031390134529148,
#  'O15.2': 0,
#  'D27.0': 0,
#  'R94.3': 0.0410958904109589,
#  'L89.5': 0,
#  'R34.': 0.10526315789473684,
#  'G95.9': 0.06363636363636363,
#  'V49.8': 0,
#  'O34.3': 0,
#  'D15.0': 0.08,
#  'T82.7': 0.6666666666666666,
#  'C61.': 0.12746858168761221,
#  'Z45.2': 0,
#  'I95.3': 0,
#  'D52.0': 0.0,
#  'Q71.3': 0,
#  'M70.5': 0.3333333333333333,
#  'F41.8': 0.08333333333333333,
#  'I23.7': 0,
#  'K82.0': 0.07692307692307693,
#  'E88.2': 0.09523809523809523,
#  'I69.1': 0,
#  'Y83.9': 0.0,
#  'S54.2': 0.0,
#  'R10.1': 0.10941086457536343,
#  'S81.0': 0.5555555555555556,
#  'Q78.0': 0.3333333333333333,
#  'S64.1': 0,
#  'C25.7': 0,
#  'C91.6': 0,
#  'M96.1': 0.0,
#  'H35.8': 0.05263157894736842,
#  'D86.8': 0.2222222222222222,
#  'O62.3': 0,
#  'J69.0': 0.5933333333333334,
#  'M16.5': 0,
#  'E25.0': 0.6666666666666666,
#  'D75.A': 0,
#  'K28.9': 0.1,
#  'S72.3': 0.4166666666666667,
#  'K51.2': 0.3333333333333333,
#  'T43.6': 0,
#  'M31.3': 0.5384615384615384,
#  'C83.5': 0,
#  'J95.7': 0,
#  'N05.5': 0.0,
#  'G80.2': 0,
#  'X50.3': 0,
#  'C18.2': 0,
#  'K26.0': 0,
#  'Z82.5': 0,
#  'D01.7': 0,
#  'M95.8': 0.0,
#  'O90.3': 0.16666666666666666,
#  'K90.9': 0.13043478260869565,
#  'H49.8': 0,
#  'Y90.6': 0,
#  'M22.2': 0.0,
#  'R00.2': 0.015364498202026806,
#  'J03.9': 0.5,
#  'B37.4': 0.375,
#  'L02.1': 0.2857142857142857,
#  'Z47.8': 0,
#  'D66.': 0.6,
#  'V27.0': 0,
#  'A93.8': 0,
#  'J38.7': 0.3333333333333333,
#  'D55.0': 0,
#  'F12.2': 0.0,
#  'R55.': 0.07897240723120837,
#  'M08.2': 0.14285714285714285,
#  'O90.8': 0.0,
#  'R74.8': 0.2413793103448276,
#  'F02.8': 0,
#  'I42.9': 0.1697381183317168,
#  'K90.0': 0.2027491408934708,
#  'J34.0': 0.25,
#  'H49.1': 1.0,
#  'L80.': 0.12,
#  'O22.3': 0,
#  'E51.1': 0.5,
#  'Y93.6': 0,
#  'Z51.5': 0,
#  'B35.3': 0.6216216216216216,
#  'W03.X': 0,
#  'C73.': 0.09090909090909091,
#  'H16.8': 0.0,
#  'K22.4': 0.35507246376811596,
#  'T36.1': 0,
#  'W17.8': 0,
#  'H47.1': 0.018691588785046728,
#  'I28.8': 0.015151515151515152,
#  'L40.5': 0.6486486486486487,
#  'Z81.4': 0,
#  'E46.': 0.2982456140350877,
#  'Q82.8': 0.047619047619047616,
#  'Z18.1': 0,
#  'Z51.6': 0,
#  'O14.2': 0,
#  'J86.0': 0.46153846153846156,
#  'S82.6': 0.5,
#  'T42.7': 0,
#  'N31.8': 0.0,
#  'I05.1': 0,
#  'L81.9': 0.015384615384615385,
#  'Z39.0': 0,
#  'T48.2': 0,
#  'G62.2': 0,
#  'K04.7': 0.3176470588235294,
#  'I97.7': 0,
#  'G11.9': 0.6,
#  'Z59.7': 0,
#  'S30.1': 0.0,
#  'L73.9': 0.3,
#  'Z65.3': 0.058823529411764705,
#  'G25.0': 0.5966386554621849,
#  'T36.3': 0,
#  'Q24.5': 0.0,
#  'S83.4': 0.5,
#  'V09.9': 0,
#  'B97.2': 0,
#  'G89.2': 0,
#  'N48.3': 0.3333333333333333,
#  'Z20.6': 0,
#  'J18.8': 0.11764705882352941,
#  'T49.1': 0,
#  'D32.9': 0.0,
#  'L98.8': 0.0036900369003690036,
#  'K71.9': 0.034482758620689655,
#  'F80.9': 0.0625,
#  'J96.1': 0.359375,
#  'J32.8': 0,
#  'I49.8': 0.021377672209026127,
#  'G71.0': 0.5454545454545454,
#  'C16.5': 0,
#  'T36.6': 0,
#  'Z20.8': 0,
#  'S43.1': 1.0,
#  'I15.0': 1.0,
#  'R33.0': 0,
#  'N32.8': 0.25572519083969464,
#  'G72.0': 0.35714285714285715,
#  'B95.5': 0.0,
#  'S75.1': 0,
#  'Y99.9': 0,
#  'F73.': 0,
#  'N05.1': 0.0625,
#  'L73.1': 0.0,
#  'E89.1': 0.0,
#  'Q86.0': 0.3333333333333333,
#  'I74.0': 0,
#  'D68.2': 0.1388888888888889,
#  'V19.9': 0.07894736842105263,
#  'K75.8': 0.16055045871559634,
#  'K40.2': 0.24,
#  'I50.3': 0,
#  'S09.2': 0,
#  'Q43.8': 0.45454545454545453,
#  'I71.0': 0.1423948220064725,
#  'S71.0': 0,
#  'Y93.3': 0,
#  'M31.1': 0.5454545454545454,
#  'W55.0': 0,
#  'J31.0': 0.07098765432098765,
#  'D63.1': 0,
#  'G56.3': 0.4444444444444444,
#  'D05.8': 0,
#  'M06.4': 0.05263157894736842,
#  'M96.3': 0.0,
#  'J10.8': 0,
#  'G37.2': 0.125,
#  'M51.3': 0.12,
#  'N70.1': 0.047619047619047616,
#  'N02.8': 0.35714285714285715,
#  'E27.2': 0.11538461538461539,
#  'N13.9': 0.1297709923664122,
#  'Z63.7': 0,
#  'S64.3': 0,
#  'C7A.1': 0,
#  'M12.5': 0.0,
#  'O86.8': 0,
#  'G62.8': 0.08333333333333333,
#  'V43.5': 0,
#  'T76.0': 0,
#  'K91.2': 0.9545454545454546,
#  'D69.2': 0.05714285714285714,
#  'F01.5': 0,
#  'Q92.8': 0,
#  'C16.1': 0,
#  'R40.4': 0,
#  'O91.1': 0,
#  'S44.0': 0,
#  'C07.': 0.14285714285714285,
#  'S72.1': 0.8064516129032258,
#  'O99.5': 0,
#  'C81.9': 0.1875,
#  'R82.9': 0.0,
#  'Y08.0': 0,
#  'D13.7': 0,
#  'R93.5': 0,
#  'N93.9': 0.04428044280442804,
#  'Z60.2': 0.0054446460980036296,
#  'I24.0': 0.0,
#  'O44.5': 0,
#  'Z16.1': 0,
#  'K60.1': 0,
#  'T36.7': 0,
#  'N81.3': 0,
#  'G24.9': 0.045871559633027525,
#  'L03.9': 0.0012674271229404308,
#  'X99.1': 0,
#  'H57.1': 0.07792207792207792,
#  'O75.8': 0,
#  'Z73.1': 0,
#  'S10.9': 0.0,
#  'E74.0': 0,
#  'D06.7': 0,
#  'S60.8': 0.0,
#  'S36.3': 0.6666666666666666,
#  'Z22.1': 0,
#  'Q62.0': 0.0,
#  'F81.8': 0.0,
#  'D56.1': 0.6363636363636364,
#  'M72.6': 0.20270270270270271,
#  'N32.9': 0.0,
#  'L60.3': 0.0,
#  'I95.1': 0.5705521472392638,
#  'C79.6': 0.0,
#  'F90.8': 0,
#  'K22.8': 0.02702702702702703,
#  'R12.': 0.004357298474945534,
#  'N80.0': 1.0,
#  'Z33.1': 0,
#  'C44.1': 0.0,
#  'L22.': 0.0,
#  'B58.2': 0.0,
#  'D67.': 0.5,
#  'K03.8': 0,
#  'L95.9': 0.0,
#  'A59.9': 0.0,
#  'B17.8': 0,
#  'Z46.2': 0,
#  'Y01.X': 0,
#  'C49.A': 0,
#  'D84.8': 0.25,
#  'T21.2': 0,
#  'T48.1': 0,
#  'I74.5': 0.2222222222222222,
#  'F88.': 0.0,
#  'M77.1': 0.0,
#  'E66.3': 0,
#  'C49.9': 0.0070921985815602835,
#  'Z94.8': 0.6,
#  'Y90.3': 0,
#  'R14.1': 0,
#  'Y71.3': 0,
#  'M79.6': 0.07390300230946882,
#  'Y93.E': 0,
#  'I67.6': 0.3333333333333333,
#  'M35.3': 0.76,
#  'E26.9': 0.10714285714285714,
#  'B48.8': 0.0,
#  'M18.1': 0,
#  'H92.2': 0.5,
#  'I63.9': 0.09133858267716535,
#  'D58.2': 0.11764705882352941,
#  'D49.4': 0,
#  'M71.2': 0,
#  'G62.1': 0.8571428571428571,
#  'S50.3': 0,
#  'C22.7': 0.0,
#  'Y65.8': 0,
#  'S67.2': 0,
#  'T83.6': 0,
#  'L43.9': 0.15384615384615385,
#  'T84.5': 0.6666666666666666,
#  'J32.4': 0.1111111111111111,
#  'T84.2': 0.0,
#  'O62.0': 0,
#  'E60.': 0,
#  'J95.4': 0,
#  'Q67.5': 0.012121212121212121,
#  'K68.9': 0,
#  'S30.8': 0.0,
#  'Q04.0': 0.3333333333333333,
#  'J45.2': 0,
#  'R57.8': 0.2777777777777778,
#  'J30.1': 0.0,
#  'I44.7': 0.4740740740740741,
#  'S00.0': 0.2,
#  'D73.4': 0.75,
#  'Q55.6': 0,
#  'K76.3': 0.3333333333333333,
#  'V03.1': 0,
#  'G43.8': 0.1,
#  'B96.6': 0,
#  'K65.4': 0,
#  'Y33.X': 0,
#  'S24.0': 0,
#  'J15.3': 0,
#  'Z89.1': 0,
#  'Z86.7': 0.2914757103574702,
#  'Y93.0': 0,
#  'C67.5': 0,
#  'J43.8': 0,
#  'B00.0': 0,
#  'W20.8': 0,
#  'S76.8': 0,
#  'F95.2': 0.6,
#  'M35.9': 0.011799410029498525,
#  'T48.3': 0.0,
#  'M23.5': 0.3333333333333333,
#  'F50.2': 0.09803921568627451,
#  'N04.0': 0,
#  'K46.0': 0,
#  'O69.0': 1.0,
#  'I77.1': 0.03333333333333333,
#  'D86.3': 1.0,
#  'O69.8': 0,
#  'C79.4': 0.05128205128205128,
#  'E56.8': 0,
#  'J95.6': 0,
#  'G93.0': 0.1891891891891892,
#  'H81.1': 0.6666666666666666,
#  'R23.3': 0.005813953488372093,
#  'H92.1': 0.0,
#  'I73.1': 0,
#  'S89.1': 0,
#  'W34.0': 0,
#  'Z63.6': 0,
#  'G03.8': 0.0625,
#  'D33.1': 0,
#  'T85.4': 0.0,
#  'I87.3': 0,
#  'R97.0': 0,
#  'R09.8': 0.002581311306143521,
#  'V49.5': 0,
#  'H33.0': 0.0,
#  'I99.8': 0,
#  'I60.2': 0,
#  'O21.8': 0,
#  'K52.9': 0.14545454545454545,
#  'G40.B': 0,
#  'K44.9': 0.2797427652733119,
#  'S42.3': 0.1320754716981132,
#  'Q60.2': 0.0,
#  'R15.2': 0,
#  'Z29.8': 0,
#  'Z88.7': 0.0,
#  'M79.2': 0.049689440993788817,
#  'Q04.8': 0.014492753623188406,
#  'S43.0': 0.2608695652173913,
#  'D25.9': 0.13109756097560976,
#  'F54.': 0,
#  'R41.0': 0.06666666666666667,
#  'N40.2': 0,
#  'V49.6': 0,
#  'T41.2': 0,
#  'D43.4': 0.125,
#  'D49.0': 0,
#  'E51.2': 0.24324324324324326,
#  'K11.6': 0.25,
#  'J38.3': 0.24444444444444444,
#  'Y83.4': 0,
#  'Q63.9': 0.5,
#  'T80.6': 0.0,
#  'Z57.2': 0,
#  'R76.8': 0.0,
#  'T81.8': 0.011235955056179775,
#  'E11.2': 0,
#  'D74.9': 0.3333333333333333,
#  'K83.8': 0.031363088057901084,
#  'D36.1': 0.0975609756097561,
#  'F16.9': 0,
#  'R00.8': 0.013888888888888888,
#  'M24.8': 0.0,
#  'T38.3': 0.5714285714285714,
#  'Q25.1': 0.07692307692307693,
#  'L30.1': 0,
#  'A04.8': 0,
#  'R53.1': 0,
#  'I05.8': 0.004273504273504274,
#  'F68.1': 0.18181818181818182,
#  'K62.5': 0.13636363636363635,
#  'T46.1': 0,
#  'D59.4': 0.0,
#  'I09.8': 0,
#  'N12.': 0.21574344023323616,
#  'K71.7': 0,
#  'Z79.5': 0,
#  'Z68.2': 0,
#  'S05.0': 0.5,
#  'Z97.8': 0,
#  'Z3A.3': 0,
#  'I82.B': 0,
#  'S73.0': 0.10714285714285714,
#  'E41.': 0.0043859649122807015,
#  'H57.0': 0.06306306306306306,
#  'T38.7': 0,
#  'S83.5': 0.0,
#  'Q79.6': 0.5,
#  'H35.9': 0.0,
#  'G58.7': 0.3333333333333333,
#  'L94.0': 0.0,
#  'N99.3': 0,
#  'K75.3': 0.4,
#  'R82.8': 0.0,
#  'O91.2': 1.0,
#  'R20.8': 0.005105296745373325,
#  'C53.0': 1.0,
#  'R54.': 0.010416666666666666,
#  'E84.0': 0,
#  'I23.6': 0,
#  'D05.9': 0.0,
#  'S39.9': 0.0,
#  'C88.0': 0.8181818181818182,
#  'H10.9': 0.26785714285714285,
#  'H44.0': 0.07692307692307693,
#  'C43.4': 0,
#  'Z77.1': 0,
#  'M21.2': 0,
#  'V00.1': 0,
#  'I35.8': 0.027522935779816515,
#  'S68.6': 0,
#  'T79.A': 0,
#  'R09.2': 0.06060606060606061,
#  'K81.0': 0.08193979933110368,
#  'C92.1': 0.7272727272727273,
#  'R41.8': 0.04572564612326044,
#  'N13.4': 0.15151515151515152,
#  'L05.9': 0.04,
#  'K31.5': 0.5116279069767442,
#  'Z99.3': 0,
#  'B37.0': 0.5822784810126582,
#  'M13.8': 0.0,
#  'R58.': 0.0020611473720371005,
#  'D49.8': 0,
#  'G89.4': 0,
#  'H34.8': 0.25,
#  'K62.3': 0.35135135135135137,
#  'O10.0': 0,
#  'R29.8': 0.050489826676714394,
#  'Z41.1': 0,
#  'W05.0': 0,
#  'D73.5': 0.2925170068027211,
#  'H81.3': 0.4,
#  'J43.2': 0.09285714285714286,
#  'I82.6': 0,
#  'T50.2': 0,
#  'F33.3': 0,
#  'I60.6': 0,
#  'K64.4': 0.3333333333333333,
#  'J96.9': 0.1188034188034188,
#  'H50.0': 0.06666666666666667,
#  'T76.1': 0,
#  'Q39.6': 0.09090909090909091,
#  'F90.0': 0.017543859649122806,
#  'N30.9': 0.17338709677419356,
#  'S01.2': 0,
#  'I82.C': 0,
#  'I05.2': 0,
#  'T84.4': 0,
#  'N48.8': 0.03076923076923077,
#  'S91.1': 0,
#  'Z93.8': 0,
#  'M80.0': 0,
#  'S64.0': 0,
#  'T45.6': 0,
#  'E86.0': 0,
#  'G45.8': 0.14285714285714285,
#  'V20.4': 0,
#  'Z85.8': 0.5,
#  'R05.': 0.023418491484184914,
#  'R71.8': 0,
#  'Q43.3': 1.0,
#  'R40.2': 0.04758064516129032,
#  'M06.0': 0.391304347826087,
#  'I44.4': 0.029411764705882353,
#  'K50.0': 0.48,
#  'I71.9': 0.020942408376963352,
#  'G04.8': 0.36363636363636365,
#  'Z89.9': 0.0,
#  'S31.1': 0,
#  'D17.9': 0.018518518518518517,
#  'S19.9': 0.0,
#  'W11.X': 0,
#  'G47.3': 0.7815668202764977,
#  'R94.4': 0.0,
#  'T75.8': 0,
#  'C25.4': 0,
#  'T87.4': 0.7142857142857143,
#  'N50.0': 0.5,
#  'I44.3': 0.031578947368421054,
#  'R04.0': 0.25769230769230766,
#  'W51.X': 0,
#  'G06.2': 0.018867924528301886,
#  'N92.5': 0,
#  'T45.8': 0,
#  'E72.8': 0,
#  'G31.9': 0.03296703296703297,
#  'G47.2': 0.0,
#  'R25.1': 0.019092066185829443,
#  'B01.0': 0,
#  'N71.1': 0.6666666666666666,
#  'S31.8': 0.0,
#  'E03.8': 0.07792207792207792,
#  'S04.0': 0.0,
#  'I49.1': 0.057692307692307696,
#  'H50.2': 0.5,
#  'B96.7': 0,
#  'D57.4': 0,
#  'Z85.1': 0,
#  'E88.0': 0.4835164835164835,
#  'I31.1': 0.21428571428571427,
#  'F15.9': 0.0,
#  'K43.0': 0.4375,
#  'G72.9': 0.0,
#  'F81.9': 0.14285714285714285,
#  'E23.6': 0.061224489795918366,
#  'K80.6': 0,
#  'Q45.3': 0.2,
#  'D43.1': 0.0,
#  'S30.2': 0.42857142857142855,
#  'Y93.4': 0,
#  'N64.8': 0.0625,
#  'H34.1': 0.75,
#  'A02.0': 0.7142857142857143,
#  'E88.4': 0,
#  'S12.2': 0,
#  'K76.1': 0.5,
#  'J45.3': 0,
#  'O69.2': 0,
#  'L30.9': 0.2222222222222222,
#  'D61.9': 0.026,
#  'S40.0': 0.0,
#  'Y04.1': 0,
#  'D86.1': 0,
#  'E03.9': 0.8287752675386445,
#  'M26.4': 0,
#  'I05.0': 0.02512562814070352,
#  'J39.2': 0.00554016620498615,
#  'S21.1': 0,
#  ...}

# %%
# Step 6: Calculate Macro Precision and Macro Recall
macro_precision = sum(precisions.values()) / len(precisions)
macro_recall = sum(recalls.values()) / len(recalls)

# %%
macro_precision
# Out:
# 0.13584406189891207

# %%
macro_recall
# Out:
# 0.2298904471107249

# %%
# Calculate F1 Score for Each ICD-10 Code
f1_scores = {}
for icd_code in unique_icd_codes:
    precision = precisions[icd_code]
    recall = recalls[icd_code]

    # Handle division by zero for precision and recall
    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)

    f1_scores[icd_code] = f1_score

# %%
# Step 8: Calculate Macro F1 Score
macro_f1_score = sum(f1_scores.values()) / len(f1_scores)

# Now you have macro precision, macro recall, and macro F1 score for your multi-label classification evaluation.

# %%
macro_f1_score
# Out:
# 0.1279583553797011

# %%
# Calculate Precision and Recall for Each ICD-10 Code
precisions = {}
recalls = {}
for icd_code in unique_icd_codes:
    TP, FP, FN, TN = counts[icd_code]
    
    # Handle division by zero
    if TP + FP == 0:
        precision = 0
    else:
        precision = TP / (TP + FP)

    if TP + FN == 0:
        recall = 0
    else:
        recall = TP / (TP + FN)
    
    precisions[icd_code] = precision
    recalls[icd_code] = recall

# Filter out zero precision values and calculate average precision
average_precision = np.mean([precision for precision in precisions.values() if precision > 0])

# %%
average_precision
# Out:
# 0.3152222872573895

# %%
average_recall = np.mean([recall for recall in recalls.values() if recall > 0])

# %%
average_recall
# Out:
# 0.5334542529418212

# %%
# Calculate F1 Score for Each ICD-10 Code
f1_scores = {}
for icd_code in unique_icd_codes:
    precision = precisions[icd_code]
    recall = recalls[icd_code]

    # Handle division by zero for precision and recall
    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)

    f1_scores[icd_code] = f1_score

# %%
average_f1 = np.mean([f1_score for f1_score in f1_scores.values() if f1_score > 0])

# %%
average_f1
# Out:
# 0.2969237292572908

# %%
len([f1_score for f1_score in f1_scores.values() if f1_score > 0])
# Out:
# 1866

# %% [markdown]
# #### Top 50 ICD codes identification

# %%
top_50_icd_codes = test_notes['icd_code'].value_counts().index[:50]
top_50_icd_codes
# Out:
# Index(['E78.5', 'I10.', 'Z87.8', 'K21.9', 'I25.1', 'Z79.0', 'F32.9', 'F41.9',
#        'N17.9', 'Z86.7', 'Z79.4', 'E03.9', 'Y92.2', 'E11.9', 'G47.3', 'F17.2',
#        'I48.9', 'D64.9', 'E66.9', 'J45.9', 'I50.3', 'Y92.9', 'Z66.', 'N39.0',
#        'E11.2', 'D62.', 'J44.9', 'I12.9', 'K59.0', 'Z68.3', 'I50.2', 'N18.9',
#        'E87.1', 'I25.2', 'Y92.0', 'Z95.5', 'G89.2', 'E87.2', 'E11.6', 'I11.0',
#        'J96.0', 'Z85.8', 'N40.0', 'N18.3', 'Z96.6', 'E11.4', 'I13.0', 'D72.8',
#        'I48.0', 'G47.0'],
#       dtype='object')

# %%
filtered_test_notes = test_notes[test_notes['icd_code'].isin(top_50_icd_codes)]

filtered_test_notes
# Out:
#          hadm_id                                               text  \
# 2       20000024  sex f medicine allergies aspirin chief complai...
# 9       20000024  sex f medicine allergies aspirin chief complai...
# 11      20002636  sex m medicine allergies prevacid ciprofloxaci...
# 13      20002636  sex m medicine allergies prevacid ciprofloxaci...
# 14      20002636  sex m medicine allergies prevacid ciprofloxaci...
# ...          ...                                                ...
# 259308  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259311  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259312  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259313  29998079  sex f medicine allergies sulfamethoxazole prav...
# 259314  29998079  sex f medicine allergies sulfamethoxazole prav...
#
#         subject_id  seq_num icd_code  icd_version
# 2       16925328.0      3.0     I10.         10.0
# 9       16925328.0     10.0    Y92.0         10.0
# 11      12527107.0      2.0    N17.9         10.0
# 13      12527107.0      4.0    I50.2         10.0
# 14      12527107.0      5.0    Z85.8         10.0
# ...            ...      ...      ...          ...
# 259308  16957952.0      8.0    I25.1         10.0
# 259311  16957952.0     11.0    E03.9         10.0
# 259312  16957952.0     12.0    K21.9         10.0
# 259313  16957952.0     13.0    D72.8         10.0
# 259314  16957952.0     14.0    I25.2         10.0
#
# [99997 rows x 6 columns]

# %%
filtered_unique_hadm_notes = filtered_test_notes[['hadm_id', 'text']].drop_duplicates(subset='hadm_id')

# %%
filtered_unique_hadm_notes = filtered_unique_hadm_notes.reset_index(drop = True)
filtered_unique_hadm_notes
# Out:
#         hadm_id                                               text
# 0      20000024  sex f medicine allergies aspirin chief complai...
# 1      20002636  sex m medicine allergies prevacid ciprofloxaci...
# 2      20002800  sex f medicine allergies penicillins tetanus t...
# 3      20003013  sex m neurology allergies no known allergies a...
# 4      20003425  sex m otolaryngology allergies no known allerg...
# ...         ...                                                ...
# 17353  29996653  sex f medicine allergies erythromycin base ato...
# 17354  29996750  sex f medicine allergies ciprofloxacin codeine...
# 17355  29997523  sex f surgery allergies no known allergies adv...
# 17356  29997858  sex m medicine allergies no known allergies ad...
# 17357  29998079  sex f medicine allergies sulfamethoxazole prav...
#
# [17358 rows x 2 columns]

# %%
filtered_icd10_data = {
    'hadm_id': [],
    'icd10_codes': []
}

# %%
unique_icd_codes = set(filtered_test_notes['icd_code'])

# %%
# Step 3: Initialize TP, FP, FN, TN counts
filtered_counts = {icd_code: (0, 0, 0, 0) for icd_code in unique_icd_codes}

# %%
i = 0
for icd_code in unique_icd_codes:
    i+=1
    if i%10 == 0:
        print(f'{i} codes are done!')
    
    true_icd_codes = filtered_test_notes[filtered_test_notes['icd_code'] == icd_code]['hadm_id'].values
    predicted_icd_codes = df_icd10[df_icd10['icd10_codes'].apply(lambda x: icd_code in x)]['hadm_id'].values

    TP = np.intersect1d(true_icd_codes, predicted_icd_codes)
    FP = np.setdiff1d(predicted_icd_codes, true_icd_codes)
    FN = np.setdiff1d(true_icd_codes, predicted_icd_codes)
    TN = len(np.union1d(predicted_icd_codes, true_icd_codes)) -len(TP) -len(FP) -len(FN)


    filtered_counts[icd_code] = (len(TP), len(FP), len(FN), TN)
# Out:
# 10 codes are done!
# 20 codes are done!
# 30 codes are done!
# 40 codes are done!
# 50 codes are done!

# %%
filtered_counts
# Out:
# {'N18.3': (0, 0, 1008, 0),
#  'E87.2': (527, 224, 626, 0),
#  'N40.0': (0, 0, 1030, 0),
#  'J96.0': (286, 111, 786, 0),
#  'G47.3': (848, 237, 1140, 0),
#  'E78.5': (3422, 660, 3171, 0),
#  'D72.8': (536, 2322, 419, 0),
#  'Z95.5': (5, 5, 1167, 0),
#  'I10.': (1028, 1709, 5492, 0),
#  'I12.9': (28, 68, 1393, 0),
#  'Z68.3': (0, 0, 1347, 0),
#  'Y92.9': (0, 0, 1720, 0),
#  'D64.9': (1278, 3053, 595, 0),
#  'Y92.0': (0, 0, 1241, 0),
#  'E11.4': (0, 0, 972, 0),
#  'N18.9': (494, 925, 793, 0),
#  'K21.9': (3549, 723, 962, 0),
#  'I11.0': (1, 1, 1134, 0),
#  'Z87.8': (14, 31, 5578, 0),
#  'J44.9': (1224, 842, 249, 0),
#  'Z86.7': (318, 773, 2474, 0),
#  'I50.3': (0, 0, 1734, 0),
#  'F41.9': (2097, 1833, 780, 0),
#  'E11.2': (0, 0, 1501, 0),
#  'G47.0': (778, 2347, 172, 0),
#  'Z79.4': (0, 0, 2317, 0),
#  'E87.1': (737, 357, 549, 0),
#  'I25.1': (1881, 638, 1918, 0),
#  'Y92.2': (0, 0, 2085, 0),
#  'E66.9': (1159, 1411, 677, 0),
#  'F17.2': (262, 199, 1712, 0),
#  'Z96.6': (0, 0, 1004, 0),
#  'F32.9': (2075, 1112, 1332, 0),
#  'I50.2': (0, 0, 1294, 0),
#  'I48.9': (1832, 1666, 139, 0),
#  'N39.0': (1025, 861, 480, 0),
#  'Z66.': (0, 0, 1560, 0),
#  'I25.2': (58, 54, 1209, 0),
#  'G89.2': (0, 0, 1155, 0),
#  'Z79.0': (0, 0, 3765, 0),
#  'Z85.8': (4, 4, 1041, 0),
#  'E11.9': (367, 602, 1651, 0),
#  'J45.9': (1482, 768, 270, 0),
#  'I48.0': (509, 106, 444, 0),
#  'N17.9': (1196, 333, 1662, 0),
#  'D62.': (16, 0, 1475, 0),
#  'K59.0': (1211, 8243, 155, 0),
#  'I13.0': (0, 0, 956, 0),
#  'E03.9': (2091, 432, 188, 0),
#  'E11.6': (93, 897, 1044, 0)}

# %%
# Calculate Precision and Recall for Each ICD-10 Code
filtered_precisions = {}
filtered_recalls = {}
for icd_code in unique_icd_codes:
    TP, FP, FN, TN = filtered_counts[icd_code]
    
    # Handle division by zero
    if TP + FP == 0:
        precision = 0
    else:
        precision = TP / (TP + FP)

    if TP + FN == 0:
        recall = 0
    else:
        recall = TP / (TP + FN)
    
    filtered_precisions[icd_code] = precision
    filtered_recalls[icd_code] = recall

# %%
filtered_precisions
# Out:
# {'N18.3': 0,
#  'E87.2': 0.7017310252996005,
#  'N40.0': 0,
#  'J96.0': 0.7204030226700252,
#  'G47.3': 0.7815668202764977,
#  'E78.5': 0.8383145516903479,
#  'D72.8': 0.18754373687893633,
#  'Z95.5': 0.5,
#  'I10.': 0.37559371574716843,
#  'I12.9': 0.2916666666666667,
#  'Z68.3': 0,
#  'Y92.9': 0,
#  'D64.9': 0.29508196721311475,
#  'Y92.0': 0,
#  'E11.4': 0,
#  'N18.9': 0.34813248766737137,
#  'K21.9': 0.8307584269662921,
#  'I11.0': 0.5,
#  'Z87.8': 0.3111111111111111,
#  'J44.9': 0.5924491771539206,
#  'Z86.7': 0.2914757103574702,
#  'I50.3': 0,
#  'F41.9': 0.533587786259542,
#  'E11.2': 0,
#  'G47.0': 0.24896,
#  'Z79.4': 0,
#  'E87.1': 0.6736745886654479,
#  'I25.1': 0.7467248908296943,
#  'Y92.2': 0,
#  'E66.9': 0.4509727626459144,
#  'F17.2': 0.5683297180043384,
#  'Z96.6': 0,
#  'F32.9': 0.6510825227486664,
#  'I50.2': 0,
#  'I48.9': 0.5237278444825615,
#  'N39.0': 0.5434782608695652,
#  'Z66.': 0,
#  'I25.2': 0.5178571428571429,
#  'G89.2': 0,
#  'Z79.0': 0,
#  'Z85.8': 0.5,
#  'E11.9': 0.37874097007223945,
#  'J45.9': 0.6586666666666666,
#  'I48.0': 0.8276422764227642,
#  'N17.9': 0.7822105951602355,
#  'D62.': 1.0,
#  'K59.0': 0.12809392849587475,
#  'I13.0': 0,
#  'E03.9': 0.8287752675386445,
#  'E11.6': 0.09393939393939393}

# %%
filtered_recalls
# Out:
# {'N18.3': 0.0,
#  'E87.2': 0.4570685169124024,
#  'N40.0': 0.0,
#  'J96.0': 0.2667910447761194,
#  'G47.3': 0.42655935613682094,
#  'E78.5': 0.519035340512665,
#  'D72.8': 0.5612565445026177,
#  'Z95.5': 0.004266211604095563,
#  'I10.': 0.15766871165644172,
#  'I12.9': 0.019704433497536946,
#  'Z68.3': 0.0,
#  'Y92.9': 0.0,
#  'D64.9': 0.6823278163374266,
#  'Y92.0': 0.0,
#  'E11.4': 0.0,
#  'N18.9': 0.3838383838383838,
#  'K21.9': 0.7867435158501441,
#  'I11.0': 0.000881057268722467,
#  'Z87.8': 0.002503576537911302,
#  'J44.9': 0.8309572301425662,
#  'Z86.7': 0.11389684813753581,
#  'I50.3': 0.0,
#  'F41.9': 0.7288842544316997,
#  'E11.2': 0.0,
#  'G47.0': 0.8189473684210526,
#  'Z79.4': 0.0,
#  'E87.1': 0.573094867807154,
#  'I25.1': 0.4951302974466965,
#  'Y92.2': 0.0,
#  'E66.9': 0.6312636165577342,
#  'F17.2': 0.13272543059777103,
#  'Z96.6': 0.0,
#  'F32.9': 0.6090402113296155,
#  'I50.2': 0.0,
#  'I48.9': 0.9294774226281075,
#  'N39.0': 0.6810631229235881,
#  'Z66.': 0.0,
#  'I25.2': 0.04577742699289661,
#  'G89.2': 0.0,
#  'Z79.0': 0.0,
#  'Z85.8': 0.003827751196172249,
#  'E11.9': 0.18186323092170467,
#  'J45.9': 0.8458904109589042,
#  'I48.0': 0.534102833158447,
#  'N17.9': 0.4184744576627012,
#  'D62.': 0.010731052984574111,
#  'K59.0': 0.8865300146412884,
#  'I13.0': 0.0,
#  'E03.9': 0.9175076788064941,
#  'E11.6': 0.08179419525065963}

# %%
# Step 6: Calculate Macro Precision and Macro Recall
macro_precision = sum(filtered_precisions.values()) / len(filtered_precisions)
macro_recall = sum(filtered_recalls.values()) / len(filtered_recalls)

# %%
macro_precision
# Out:
# 0.36444586070714435

# %%
macro_recall
# Out:
# 0.29479248464857305

# %%
# Calculate F1 Score for Each ICD-10 Code
filtered_f1_scores = {}
for icd_code in unique_icd_codes:
    precision = filtered_precisions[icd_code]
    recall = filtered_recalls[icd_code]

    # Handle division by zero for precision and recall
    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)

    filtered_f1_scores[icd_code] = f1_score

# %%
# Step 8: Calculate Macro F1 Score
macro_f1_score = sum(filtered_f1_scores.values()) / len(filtered_f1_scores)

# Now you have macro precision, macro recall, and macro F1 score for your multi-label classification evaluation.

# %%
macro_f1_score
# Out:
# 0.2693193129654034

# %%
# Calculate Precision and Recall for Each ICD-10 Code
filtered_precisions = {}
filtered_recalls = {}
for icd_code in unique_icd_codes:
    TP, FP, FN, TN = filtered_counts[icd_code]
    
    # Handle division by zero
    if TP + FP == 0:
        precision = 0
    else:
        precision = TP / (TP + FP)

    if TP + FN == 0:
        recall = 0
    else:
        recall = TP / (TP + FN)
    
    filtered_precisions[icd_code] = precision
    filtered_recalls[icd_code] = recall    
    
    
    
    
    
# Filter out zero precision values and calculate average precision
average_precision = np.mean([precision for precision in filtered_precisions.values() if precision > 0])

# %%
average_precision
# Out:
# 0.5359497951575651

# %%
average_recall = np.mean([recall for recall in filtered_recalls.values() if recall > 0])

# %%
average_recall
# Out:
# 0.4335183597773133

# %%
# Calculate F1 Score for Each ICD-10 Code
filtered_f1_scores = {}
for icd_code in unique_icd_codes:
    precision = filtered_precisions[icd_code]
    recall = filtered_recalls[icd_code]

    # Handle division by zero for precision and recall
    if precision + recall == 0:
        f1_score = 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)

    filtered_f1_scores[icd_code] = f1_score

# %%
average_f1 = np.mean([f1_score for f1_score in filtered_f1_scores.values() if f1_score > 0])

# %%
average_f1
# Out:
# 0.39605781318441674
